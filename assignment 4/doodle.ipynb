# %%
# import networkx as nx
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
import mgclient

# %%
# Make a connection to the database
conn = mgclient.connect(host='127.0.0.1', port=7687)

# Create a cursor for query execution
cursor = conn.cursor()

def query(query):
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# ## community detection

# %%
# community detection, louvain algo

q = '''CALL community_detection.get()
YIELD node, community_id
WITH node, community_id
WHERE 'User' IN labels(node)
SET node.community = community_id
RETURN node, community_id;'''

res = query(q)

# %%
def extract(node):
    data = {
        'id': node.id,
        'label': node.labels,
        **node.properties
    }
    return data

users = pd.DataFrame({i[0].id:extract(i[0]) for i in res}).T

# %%
users
# Out:
#             id   label community                 created_at  \
# 805384  805384  {User}         0  2014-03-15T10:39:00+00:00
# 805385  805385  {User}         6  2010-05-15T08:47:16+00:00
# 805386  805386  {User}         1  2014-08-21T13:58:31+00:00
# 805387  805387  {User}         3  2021-03-19T12:27:36+00:00
# 805388  805388  {User}         4  2011-09-09T14:05:20+00:00
# ...        ...     ...       ...                        ...
# 896001  896001  {User}         8  2024-04-30T23:47:59+00:00
# 896002  896002  {User}         8  2023-12-10T08:16:32+00:00
# 896003  896003  {User}         6  2015-01-13T17:14:06+00:00
# 896004  896004  {User}         6  2022-12-13T10:03:37+00:00
# 896005  896005  {User}         6  2024-04-23T11:12:03+00:00
#
#                                               description favourites_count  \
# 805384  apotheker, schepen van financiën Evergem, fede...              807
# 805385  Député Bruxellois , Président du Groupe PS - @...            14789
# 805386  Welcome to Dominion! Collect heroes, create te...               16
# 805387  The platform engineering guy. 👾 I ask the best...             1046
# 805388  Parlementslid | West-Vlaams Lijsttrekker @de_N...             8548
# ...                                                   ...              ...
# 896001     Éducation. Enseignant. Voyage. vidéo. Écriture                0
# 896002  Enraptured by #limitless 🔥NFT Marketplace🔥 🔥 C...                0
# 896003                                                                 760
# 896004                                                                 609
# 896005                                                                   0
#
#        followers_count friends_count                ident is_blue_verified  \
# 805384            4390           605           2390807984             True
# 805385            4264          1898            144099318            False
# 805386           35541             0           2752235233             True
# 805387           31265           189  1372887446669647875             True
# 805388           18505          1851            370709666             True
# ...                ...           ...                  ...              ...
# 896001               0             0  1785456092090171392            False
# 896002              19             0  1733762597025972224            False
# 896003               6            80           2976761255            False
# 896004              13            41  1602605066627727360            False
# 896005               1             0  1782729123573497856            False
#
#        listed_count                  location media_count  \
# 805384           49                                   521
# 805385           86                 Evere....        2070
# 805386          111                                     2
# 805387          245                                   933
# 805388          213  Koksijde - Oostduinkerke        4249
# ...             ...                       ...         ...
# 896001            0                    France           0
# 896002            0                    Naples           1
# 896003            0                                     7
# 896004            0                                     0
# 896005            0                 Baltimore           1
#
#                         name normal_followers_count possibly_sensitive  \
# 805384    kathleen depoorter                   4390              False
# 805385       Ridouane Chahid                   4264              False
# 805386             Hero Wars                  35541              False
# 805387                  Luca                  31265              False
# 805388         Sander Loones                  18505              False
# ...                      ...                    ...                ...
# 896001  Anne-Claire Sylvie🤵🍓                      0              False
# 896002           Nigel Calen                     19              False
# 896003           Vicduquenoy                      6              False
# 896004  Martine Demillequand                     13              False
# 896005                Kiesha                      1              False
#
#             screen_name statuses_count verified
# 805384     KDepoorterMP           2328    False
# 805385   RidouaneChahid          15501    False
# 805386      HeroWarsWeb              2    False
# 805387       luca_cloud           2776    False
# 805388     SanderLoones          19280    False
# ...                 ...            ...      ...
# 896001  captainpinprick              3    False
# 896002       calen13662              1    False
# 896003      vicduquenoy            364    False
# 896004  MartineDemille1             10    False
# 896005      Kiesha67278             55    False
#
# [90622 rows x 19 columns]

# %%
# a large number of identified communities are super small (1-4 members), while the largest on has over 20k member
users.groupby('community')['id'].count().value_counts().sort_index()
# Out:
# 1        1717
# 2         199
# 3          19
# 4           8
# 5           1
# 7           1
# 11          1
# 13          1
# 22          1
# 25          2
# 26          1
# 38          1
# 54          1
# 70          2
# 77          1
# 92          1
# 96          1
# 97          1
# 106         1
# 128         1
# 131         1
# 133         1
# 155         1
# 185         1
# 200         1
# 203         1
# 212         1
# 248         1
# 261         1
# 387         1
# 393         1
# 464         1
# 484         1
# 485         1
# 575         1
# 625         1
# 670         1
# 842         1
# 861         1
# 887         1
# 1003        1
# 1023        1
# 1182        1
# 1321        1
# 1523        1
# 1551        1
# 1876        1
# 2344        1
# 2361        1
# 2701        1
# 2733        1
# 3013        1
# 4298        1
# 4655        1
# 6336        1
# 8522        1
# 11189       1
# 21424       1
# Name: id, dtype: int64

# %% [markdown]
# ## engagement by politican

# %%
# engagements by politician 

q = '''MATCH (u:User)-[:MEMBER_OF]->(p:Party), (u)-[:POSTED]->(t:Tweet)
WITH u.name AS Politician, p.ident AS Party, AVG(t.reply_count) AS AvgReply, AVG(t.retweet_count) AS AvgRetweet, AVG(t.favorite_count) AS AvgLikes, count(t) AS NumTweets
ORDER BY AvgReply DESC
RETURN Politician, Party, AvgReply, AvgRetweet, AvgLikes, NumTweets'''

pol_eng = query(q)

# %%
df_pol_eng = pd.DataFrame(pol_eng, columns='Politician, Party, AvgReply, AvgRetweet, AvgLikes, NumTweets'.split(',')).round(1)
df_pol_eng
# Out:
#              Politician        Party   AvgReply   AvgRetweet   AvgLikes  \
# 0              Emir KIR        ONAFH      233.7         24.8      106.4
# 1    Melissa Depraetere      Vooruit      144.8         48.9       98.0
# 2        Darya Safai MP         N-VA       66.7        525.6      718.5
# 3     Wouter De Vriendt  Ecolo-Groen       66.3        457.9       46.0
# 4         Kristof Calvo  Ecolo-Groen       45.1          7.0       41.0
# ..                  ...          ...        ...          ...        ...
# 132       Olivier Vajda  Ecolo-Groen        0.0         14.3        0.1
# 133      Philippe TISON           PS        0.0         37.2        0.1
# 134    Stefaan Vanhecke  Ecolo-Groen        0.0         11.0        0.0
# 135       Erik Gilissen           VB        0.0         46.3        1.5
# 136   Jean-Marc Delizée           PS        0.0        245.3        0.0
#
#       NumTweets
# 0            31
# 1            36
# 2           245
# 3            50
# 4            42
# ..          ...
# 132          35
# 133          20
# 134           2
# 135          28
# 136          22
#
# [137 rows x 6 columns]

# %% [markdown]
# maybe let's see who's spewing nonsense, and whether people buy it?

# %%
# which politician got community-noted? does the engagement increase?

q = '''MATCH (u:User)-[:MEMBER_OF]->(p:Party), (u)-[:POSTED]->(t:Tweet), (u)-[:POSTED]->(tc:Tweet {has_birdwatch_notes: True})
WITH u.name AS Politician, p.ident AS Party,
AVG(t.reply_count) AS AvgReply, AVG(t.retweet_count) AS AvgRetweet, AVG(t.favorite_count) AS AvgLikes, count(t) AS NumTweets,
AVG(tc.reply_count) AS AvgReplyCN, AVG(tc.retweet_count) AS AvgRetweetCN, AVG(tc.favorite_count) AS AvgLikesCN, count(tc) AS NumTweetsCN
ORDER BY AvgReply DESC
RETURN Politician, Party, AvgReply, AvgRetweet, AvgLikes, NumTweets, AvgReplyCN, AvgRetweetCN, AvgLikesCN, NumTweetsCN'''

cn_eng = query(q)

# %%
df_cn_eng = pd.DataFrame(cn_eng, columns='Politician, Party, AvgReply, AvgRetweet, AvgLikes, NumTweets, AvgReplyCN, AvgRetweetCN, AvgLikesCN, NumTweetsCN'.split(',')).round(1)
df_cn_eng
# Out:
#                  Politician        Party   AvgReply   AvgRetweet   AvgLikes  \
# 0                  Emir KIR        ONAFH       81.6         10.5       45.0
# 1            Darya Safai MP         N-VA       66.3        525.9      716.5
# 2          Theo Francken MP         N-VA       22.8        171.7      107.1
# 3                 Kim Buyst  Ecolo-Groen       20.8         10.0        6.6
# 4          Michael Freilich         N-VA       19.6         43.2       76.8
# 5           Peter De Roover         N-VA       17.2         33.8      160.5
# 6            Raoul Hedebouw     PVDA-PTB       16.3         20.7       41.7
# 7       Joris Vandenbroucke      Vooruit       15.9         10.2       13.5
# 8          Peter Mertens MP     PVDA-PTB       12.6         53.0       28.4
# 9             Denis Ducarme           MR       11.3         12.2       44.6
# 10           Simon Moutquin  Ecolo-Groen        8.3         67.4       20.4
# 11  Marie Christine Marghem           MR        5.2          3.0       17.3
# 12             Sofie Merckx     PVDA-PTB        3.1          9.2       11.4
#
#      NumTweets   AvgReplyCN   AvgRetweetCN   AvgLikesCN   NumTweetsCN
# 0           30       4798.0          455.0       1949.0            30
# 1          732        162.3          439.3       1213.7           732
# 2         8888        169.4           56.5        435.0          8888
# 3           42        283.0            7.0         27.0            42
# 4          924        115.7           49.3        213.3           924
# 5          119        189.0            9.0        146.0           119
# 6          325        132.0           19.0         53.0           325
# 7          419        135.0            6.0         42.0           419
# 8         1143         69.3           19.3         69.3          1143
# 9          948         75.8           48.5        222.8           948
# 10         330         37.3           38.0        138.7           330
# 11         349         36.0           73.0        266.0           349
# 12         477          8.0           14.0         30.0           477

# %%
q = '''MATCH (u:User)-[:MEMBER_OF]->(p:Party), (u)-[:POSTED]->(tc:Tweet {has_birdwatch_notes: True})
RETURN u.name, p.ident, tc.birdwatch_classification, tc.full_text'''

cn_tweets = query(q)

# %%
# unfortunately, very few of the tweets are classified, en ik spreek geen nederlands (?)
df_cn_tweets = pd.DataFrame(cn_tweets)
df_cn_tweets
# Out:
#                           0            1                                   2  \
# 0            Darya Safai MP         N-VA                                None
# 1            Darya Safai MP         N-VA                                None
# 2            Simon Moutquin  Ecolo-Groen                                None
# 3          Peter Mertens MP     PVDA-PTB  MisinformedOrPotentiallyMisleading
# 4          Peter Mertens MP     PVDA-PTB                                None
# 5          Theo Francken MP         N-VA                                None
# 6            Simon Moutquin  Ecolo-Groen                                None
# 7          Theo Francken MP         N-VA                                None
# 8             Denis Ducarme           MR                                None
# 9          Theo Francken MP         N-VA                                None
# 10         Theo Francken MP         N-VA                                None
# 11         Theo Francken MP         N-VA                                None
# 12             Sofie Merckx     PVDA-PTB                                None
# 13         Peter Mertens MP     PVDA-PTB                                None
# 14           Darya Safai MP         N-VA                                None
# 15         Theo Francken MP         N-VA                                None
# 16                Kim Buyst  Ecolo-Groen                                None
# 17           Simon Moutquin  Ecolo-Groen                                None
# 18         Michael Freilich         N-VA                                None
# 19            Denis Ducarme           MR                                None
# 20            Denis Ducarme           MR                                None
# 21         Michael Freilich         N-VA                                None
# 22          Peter De Roover         N-VA                                None
# 23           Raoul Hedebouw     PVDA-PTB                                None
# 24            Denis Ducarme           MR                                None
# 25         Theo Francken MP         N-VA  MisinformedOrPotentiallyMisleading
# 26         Michael Freilich         N-VA                                None
# 27         Theo Francken MP         N-VA                                None
# 28                 Emir KIR        ONAFH                                None
# 29      Joris Vandenbroucke      Vooruit                                None
# 30  Marie Christine Marghem           MR                                None
#
#                                                     3
# 0   Ongelofelijk!In het Brusselse Parlement: een b...
# 1   Which surah from the Quran did the Imam actual...
# 2   Palestine: 4 manifs organisées par la société ...
# 3   Alle fiscale constructies van miljardairs en m...
# 4   Voor @PieterVBO is eerlijke fiscaliteit alleen...
# 5   24.620 martelaren.‘Martelaren’, ‘shahids’, gee...
# 6   (1/2) Les propos de l'ambassadrice d'Israel so...
# 7   Zwak leiderschap zorgt voor een zwak Westen. W...
# 8   On a retrouvé de la cocaïne dans le cabinet de...
# 9   Majeure juridische overwinning voor Israël. St...
# 10  Links houdt ervan rechtse politici af te schil...
# 11  Rusland moet van het Strafhof onmiddellijk elk...
# 12  Ce matin dans @lecho @AlexiaBertrand_plaide po...
# 13  Nieuwe berekeningen van het federaal Planburea...
# 14  Welke soera uit de Koran zong de Imam eigenlij...
# 15  Goed dat zo veel Vlamingen Bart steunen om pre...
# 16  Op de vraag of Belgie een herdenkingsdag moet ...
# 17  Pour toutes celles et ceux qui ont depuis des ...
# 18  Gelukkig gaat @de_NVA hier niet in mee. Politi...
# 19  Boycotter les artistes d’un pays, alors que l’...
# 20  @frandisi Ah ? La Russie a subi sur son sol un...
# 21  Om klaarheid te scheppen bij dergelijke (Arabi...
# 22  Wat denken jullie van smulsneetje als alternat...
# 23  Het beleid van Vivaldi:+19% voor de dividenden...
# 24  La ministre de la Défense veut bien envoyer no...
# 25  Beste mensen,Vandaag vindt het Suikerfeest pla...
# 26  Toch opmerkelijk dat Israël steeds meer Arabis...
# 27  Ballistische(!) raketten van de ayatollahs zij...
# 28  J'ai pris un arrêté du Bourgmestre pour interd...
# 29  Veiligheid of laksheid in het verkeer? Kies ma...
# 30  Ce fut le cas en Belgique en 2003 quand les ve...

# %%
# how do you do dutch sentiment analysis?

# %%
q = '''MATCH (u:User)-[:MEMBER_OF]->(p:Party)
CALL degree_centrality.get()
YIELD node, degree
RETURN node, degree'''

cent_deg = query(q)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # sentiment analysis

# %%
q = '''
match (t:Tweet)
return *
'''

temp = query(q)

# %%
tweets = pd.DataFrame([i[0].properties for i in temp])

# %%
q = '''
match (p:Party) <-[:MEMBER_OF]- (u:User) -[:POSTED]-> (t:Tweet)
return p, u, t
'''

pol_tweets = query(q)

# %%
pol_tweets[0]
# Out:
# (<mgclient.Node(id=929337, labels={'Party'}, properties={'ident': 'N-VA'}) at 0x0000020E72BE11D0>,
#  <mgclient.Node(id=805384, labels={'User'}, properties={'community': 0, 'created_at': '2014-03-15T10:39:00+00:00', 'description': 'apotheker, schepen van financiën Evergem, federaal volksvertegenwoordiger N-VA , commissie volksgezondheid ,commissie financiën, ontwikkelingssamenwerking.', 'favourites_count': 807, 'followers_count': 4390, 'friends_count': 605, 'ident': '2390807984', 'is_blue_verified': True, 'listed_count': 49, 'location': '', 'media_count': 521, 'name': 'kathleen depoorter', 'normal_followers_count': 4390, 'possibly_sensitive': False, 'screen_name': 'KDepoorterMP', 'statuses_count': 2328, 'verified': False}) at 0x0000020E72BE0ED0>,
#  <mgclient.Node(id=464674, labels={'Tweet'}, properties={'created_at': '2024-02-18T17:37:46+00:00', 'favorite_count': 93, 'full_text': 'Schokkende beelden: “UNRWA-medewerker neemt lichaam van vermoorde Israëliër mee in voertuig tijdens Hamas-aanval op kibboets” https://t.co/4VLAFuTKVz', 'has_birdwatch_notes': False, 'ident': '1759271000850501861', 'lang': 'nl', 'quote_count': 3, 'reply_count': 19, 'retweet_count': 30, 'views_count': 8025}) at 0x0000020E72BE0DE0>)

# %%
pol_tweets = pd.DataFrame([{'party':i[0], 'user':i[1], **i[2].properties} for i in pol_tweets])

# %%
pol_tweets
# Out:
#                             party  \
# 0      (:Party {'ident': 'N-VA'})
# 1      (:Party {'ident': 'N-VA'})
# 2      (:Party {'ident': 'N-VA'})
# 3      (:Party {'ident': 'N-VA'})
# 4      (:Party {'ident': 'N-VA'})
# ...                           ...
# 16833    (:Party {'ident': 'VB'})
# 16834    (:Party {'ident': 'VB'})
# 16835    (:Party {'ident': 'VB'})
# 16836    (:Party {'ident': 'VB'})
# 16837    (:Party {'ident': 'VB'})
#
#                                                     user  \
# 0      (:User {'community': 0, 'created_at': '2014-03...
# 1      (:User {'community': 0, 'created_at': '2014-03...
# 2      (:User {'community': 0, 'created_at': '2014-03...
# 3      (:User {'community': 0, 'created_at': '2014-03...
# 4      (:User {'community': 0, 'created_at': '2014-03...
# ...                                                  ...
# 16833  (:User {'community': 5, 'created_at': '2010-02...
# 16834  (:User {'community': 5, 'created_at': '2010-02...
# 16835  (:User {'community': 5, 'created_at': '2010-02...
# 16836  (:User {'community': 5, 'created_at': '2010-02...
# 16837  (:User {'community': 5, 'created_at': '2010-02...
#
#                       created_at  favorite_count  \
# 0      2024-02-18T17:37:46+00:00              93
# 1      2024-02-18T12:13:18+00:00             445
# 2      2024-02-17T12:16:23+00:00              11
# 3      2024-02-17T06:29:11+00:00             251
# 4      2024-02-16T12:33:31+00:00              31
# ...                          ...             ...
# 16833  2024-05-02T13:46:52+00:00               0
# 16834  2024-05-02T13:46:24+00:00               0
# 16835  2024-05-02T11:06:30+00:00               0
# 16836  2024-05-02T10:55:57+00:00               0
# 16837  2024-05-01T14:35:11+00:00               0
#
#                                                full_text  has_birdwatch_notes  \
# 0      Schokkende beelden: “UNRWA-medewerker neemt li...                False
# 1      Vierdaagse werkweek van 32 uur, jongeren meer ...                False
# 2      @de_NVA #voorVlaamsewelvaert https://t.co/74d2...                False
# 3      UNWRA:Minstens 30 medewerkers zouden volgens I...                False
# 4      1048 Jongeren tussen 18 en 24 jaar werden er i...                False
# ...                                                  ...                  ...
# 16833  RT @vlbelang: "Wij zijn zeker bereid om compro...                False
# 16834  RT @vlbelang: "Dit zijn de typische linkse rec...                False
# 16835  RT @PBoonefaes: "On sociaal te zijn hebben we ...                False
# 16836  RT @PALNWS: "Als vroeger onze competitiviteit ...                False
# 16837  RT @V_N1WS: "Als Kabouter Lui een lidkaart zou...                False
#
#                      ident lang  quote_count  reply_count  retweet_count  \
# 0      1759271000850501861   nl            3           19             30
# 1      1759189343275466980   nl            8          109             80
# 2      1758827733210071107  qme            0            0              0
# 3      1758740358400274623   nl            8           63             88
# 4      1758469657986564350   nl            2           10              5
# ...                    ...  ...          ...          ...            ...
# 16833  1786029594715324608   nl            0            0              7
# 16834  1786029474951115134   nl            0            0              3
# 16835  1785989235729695007   nl            0            0              2
# 16836  1785986579661476153   nl            0            0              1
# 16837  1785679364308267113   nl            0            0             11
#
#        views_count ranked_classification birdwatch_classification  \
# 0           8025.0                   NaN                      NaN
# 1          34771.0                   NaN                      NaN
# 2            272.0                   NaN                      NaN
# 3          14767.0                   NaN                      NaN
# 4           1541.0                   NaN                      NaN
# ...            ...                   ...                      ...
# 16833          NaN                   NaN                      NaN
# 16834          NaN                   NaN                      NaN
# 16835          NaN                   NaN                      NaN
# 16836          NaN                   NaN                      NaN
# 16837          NaN                   NaN                      NaN
#
#       birdwatch_tags
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 16833            NaN
# 16834            NaN
# 16835            NaN
# 16836            NaN
# 16837            NaN
#
# [16838 rows x 15 columns]

# %%
dutch_tweets = pol_tweets[pol_tweets['lang'] == 'nl']

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from transformers import pipeline
import torch

# %%
model_name = "DTAI-KULeuven/robbert-v2-dutch-sentiment"
model = RobertaForSequenceClassification.from_pretrained(model_name)
tokenizer = RobertaTokenizer.from_pretrained(model_name)

classifier = pipeline('sentiment-analysis', model=model, tokenizer = tokenizer, device=0)

# %%
device = torch.device('cuda')
model.to(device)
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(40000, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
sentiment = classifier(dutch_tweets['full_text'].to_list())

# %%
sentiment
# Out:
# [{'label': 'Negative', 'score': 0.9339827299118042},
#  {'label': 'Positive', 'score': 0.9970736503601074},
#  {'label': 'Positive', 'score': 0.9728376865386963},
#  {'label': 'Positive', 'score': 0.9990109205245972},
#  {'label': 'Positive', 'score': 0.9985503554344177},
#  {'label': 'Positive', 'score': 0.997927188873291},
#  {'label': 'Positive', 'score': 0.8989135026931763},
#  {'label': 'Positive', 'score': 0.7390094995498657},
#  {'label': 'Positive', 'score': 0.9935051202774048},
#  {'label': 'Negative', 'score': 0.8849559426307678},
#  {'label': 'Positive', 'score': 0.999193012714386},
#  {'label': 'Positive', 'score': 0.9236530661582947},
#  {'label': 'Positive', 'score': 0.9991877675056458},
#  {'label': 'Positive', 'score': 0.99257892370224},
#  {'label': 'Positive', 'score': 0.910633385181427},
#  {'label': 'Positive', 'score': 0.9252086877822876},
#  {'label': 'Positive', 'score': 0.9961661100387573},
#  {'label': 'Positive', 'score': 0.9989672899246216},
#  {'label': 'Positive', 'score': 0.9713600277900696},
#  {'label': 'Positive', 'score': 0.9996005892753601},
#  {'label': 'Positive', 'score': 0.9972012042999268},
#  {'label': 'Positive', 'score': 0.9968838095664978},
#  {'label': 'Positive', 'score': 0.975310206413269},
#  {'label': 'Positive', 'score': 0.9973042011260986},
#  {'label': 'Positive', 'score': 0.9825692176818848},
#  {'label': 'Positive', 'score': 0.9978336691856384},
#  {'label': 'Positive', 'score': 0.9461002349853516},
#  {'label': 'Negative', 'score': 0.6692696809768677},
#  {'label': 'Positive', 'score': 0.9985321760177612},
#  {'label': 'Positive', 'score': 0.9939711689949036},
#  {'label': 'Positive', 'score': 0.9634799957275391},
#  {'label': 'Positive', 'score': 0.996187150478363},
#  {'label': 'Positive', 'score': 0.9984651803970337},
#  {'label': 'Positive', 'score': 0.9913909435272217},
#  {'label': 'Positive', 'score': 0.9959442019462585},
#  {'label': 'Positive', 'score': 0.98492032289505},
#  {'label': 'Negative', 'score': 0.9586573243141174},
#  {'label': 'Positive', 'score': 0.5242379903793335},
#  {'label': 'Positive', 'score': 0.831092357635498},
#  {'label': 'Positive', 'score': 0.9756913781166077},
#  {'label': 'Positive', 'score': 0.9008161425590515},
#  {'label': 'Negative', 'score': 0.5168166160583496},
#  {'label': 'Positive', 'score': 0.9698183536529541},
#  {'label': 'Negative', 'score': 0.999790608882904},
#  {'label': 'Positive', 'score': 0.9354062080383301},
#  {'label': 'Positive', 'score': 0.985550045967102},
#  {'label': 'Positive', 'score': 0.9943920969963074},
#  {'label': 'Positive', 'score': 0.8221210837364197},
#  {'label': 'Positive', 'score': 0.9953678846359253},
#  {'label': 'Positive', 'score': 0.9993785619735718},
#  {'label': 'Negative', 'score': 0.9984472393989563},
#  {'label': 'Positive', 'score': 0.9982197880744934},
#  {'label': 'Positive', 'score': 0.8944841027259827},
#  {'label': 'Negative', 'score': 0.9091404676437378},
#  {'label': 'Negative', 'score': 0.6390684843063354},
#  {'label': 'Negative', 'score': 0.9995864033699036},
#  {'label': 'Positive', 'score': 0.9880361557006836},
#  {'label': 'Positive', 'score': 0.9500990509986877},
#  {'label': 'Negative', 'score': 0.9989370703697205},
#  {'label': 'Negative', 'score': 0.6182766556739807},
#  {'label': 'Positive', 'score': 0.7025842070579529},
#  {'label': 'Positive', 'score': 0.9896411299705505},
#  {'label': 'Positive', 'score': 0.9113218188285828},
#  {'label': 'Positive', 'score': 0.5888250470161438},
#  {'label': 'Positive', 'score': 0.9758340120315552},
#  {'label': 'Positive', 'score': 0.9693483710289001},
#  {'label': 'Positive', 'score': 0.9990658164024353},
#  {'label': 'Positive', 'score': 0.9012728929519653},
#  {'label': 'Positive', 'score': 0.9656602144241333},
#  {'label': 'Positive', 'score': 0.9544814229011536},
#  {'label': 'Positive', 'score': 0.9981287121772766},
#  {'label': 'Positive', 'score': 0.9986316561698914},
#  {'label': 'Positive', 'score': 0.9996289014816284},
#  {'label': 'Positive', 'score': 0.9729141592979431},
#  {'label': 'Positive', 'score': 0.9833595752716064},
#  {'label': 'Positive', 'score': 0.9990538954734802},
#  {'label': 'Negative', 'score': 0.9932782053947449},
#  {'label': 'Positive', 'score': 0.9397804141044617},
#  {'label': 'Negative', 'score': 0.9970754384994507},
#  {'label': 'Positive', 'score': 0.9972003698348999},
#  {'label': 'Positive', 'score': 0.9996616840362549},
#  {'label': 'Positive', 'score': 0.991400420665741},
#  {'label': 'Positive', 'score': 0.998047947883606},
#  {'label': 'Positive', 'score': 0.9981300234794617},
#  {'label': 'Positive', 'score': 0.9983017444610596},
#  {'label': 'Negative', 'score': 0.999767005443573},
#  {'label': 'Negative', 'score': 0.9977502226829529},
#  {'label': 'Positive', 'score': 0.699791431427002},
#  {'label': 'Positive', 'score': 0.873972475528717},
#  {'label': 'Positive', 'score': 0.9960193037986755},
#  {'label': 'Positive', 'score': 0.9990468621253967},
#  {'label': 'Negative', 'score': 0.9944943785667419},
#  {'label': 'Positive', 'score': 0.9980113506317139},
#  {'label': 'Positive', 'score': 0.9968963861465454},
#  {'label': 'Positive', 'score': 0.9997124075889587},
#  {'label': 'Negative', 'score': 0.9997261166572571},
#  {'label': 'Positive', 'score': 0.9939742684364319},
#  {'label': 'Negative', 'score': 0.999228835105896},
#  {'label': 'Negative', 'score': 0.9216422438621521},
#  {'label': 'Negative', 'score': 0.9862034320831299},
#  {'label': 'Positive', 'score': 0.602811336517334},
#  {'label': 'Positive', 'score': 0.99945467710495},
#  {'label': 'Positive', 'score': 0.9988534450531006},
#  {'label': 'Positive', 'score': 0.9987074136734009},
#  {'label': 'Positive', 'score': 0.9995332956314087},
#  {'label': 'Positive', 'score': 0.9963416457176208},
#  {'label': 'Negative', 'score': 0.9996682405471802},
#  {'label': 'Negative', 'score': 0.9361072778701782},
#  {'label': 'Positive', 'score': 0.9971127510070801},
#  {'label': 'Positive', 'score': 0.9994164705276489},
#  {'label': 'Positive', 'score': 0.9995446801185608},
#  {'label': 'Positive', 'score': 0.7952728271484375},
#  {'label': 'Positive', 'score': 0.6083085536956787},
#  {'label': 'Positive', 'score': 0.9992714524269104},
#  {'label': 'Positive', 'score': 0.9996585845947266},
#  {'label': 'Positive', 'score': 0.9995793700218201},
#  {'label': 'Positive', 'score': 0.9741722345352173},
#  {'label': 'Positive', 'score': 0.9910762310028076},
#  {'label': 'Negative', 'score': 0.9979668259620667},
#  {'label': 'Negative', 'score': 0.9719176888465881},
#  {'label': 'Negative', 'score': 0.9996781349182129},
#  {'label': 'Negative', 'score': 0.9962766766548157},
#  {'label': 'Negative', 'score': 0.9701695442199707},
#  {'label': 'Positive', 'score': 0.9377530217170715},
#  {'label': 'Positive', 'score': 0.9971287846565247},
#  {'label': 'Positive', 'score': 0.9964755177497864},
#  {'label': 'Positive', 'score': 0.9809424877166748},
#  {'label': 'Positive', 'score': 0.9949853420257568},
#  {'label': 'Positive', 'score': 0.9987712502479553},
#  {'label': 'Positive', 'score': 0.9990197420120239},
#  {'label': 'Positive', 'score': 0.995960533618927},
#  {'label': 'Negative', 'score': 0.9994722008705139},
#  {'label': 'Positive', 'score': 0.7480742335319519},
#  {'label': 'Positive', 'score': 0.8326218128204346},
#  {'label': 'Positive', 'score': 0.9965296387672424},
#  {'label': 'Positive', 'score': 0.9751737117767334},
#  {'label': 'Positive', 'score': 0.9486832022666931},
#  {'label': 'Positive', 'score': 0.9874892830848694},
#  {'label': 'Negative', 'score': 0.8917098641395569},
#  {'label': 'Negative', 'score': 0.9849686026573181},
#  {'label': 'Negative', 'score': 0.610136866569519},
#  {'label': 'Positive', 'score': 0.9724898338317871},
#  {'label': 'Negative', 'score': 0.9990309476852417},
#  {'label': 'Positive', 'score': 0.9990800619125366},
#  {'label': 'Positive', 'score': 0.9964939951896667},
#  {'label': 'Negative', 'score': 0.9945055842399597},
#  {'label': 'Positive', 'score': 0.8830777406692505},
#  {'label': 'Negative', 'score': 0.998799204826355},
#  {'label': 'Negative', 'score': 0.9997244477272034},
#  {'label': 'Positive', 'score': 0.833763599395752},
#  {'label': 'Positive', 'score': 0.9558771848678589},
#  {'label': 'Positive', 'score': 0.9629594087600708},
#  {'label': 'Positive', 'score': 0.8610143661499023},
#  {'label': 'Positive', 'score': 0.8589254021644592},
#  {'label': 'Negative', 'score': 0.9965060949325562},
#  {'label': 'Negative', 'score': 0.9836570620536804},
#  {'label': 'Negative', 'score': 0.9848836660385132},
#  {'label': 'Positive', 'score': 0.9933226704597473},
#  {'label': 'Positive', 'score': 0.9952164888381958},
#  {'label': 'Negative', 'score': 0.9881553649902344},
#  {'label': 'Positive', 'score': 0.5207112431526184},
#  {'label': 'Positive', 'score': 0.7316362857818604},
#  {'label': 'Negative', 'score': 0.9869950413703918},
#  {'label': 'Positive', 'score': 0.9964544773101807},
#  {'label': 'Positive', 'score': 0.997118353843689},
#  {'label': 'Positive', 'score': 0.9682074189186096},
#  {'label': 'Negative', 'score': 0.9898731708526611},
#  {'label': 'Negative', 'score': 0.5511987209320068},
#  {'label': 'Positive', 'score': 0.9993667006492615},
#  {'label': 'Positive', 'score': 0.993158757686615},
#  {'label': 'Positive', 'score': 0.9978074431419373},
#  {'label': 'Positive', 'score': 0.999548614025116},
#  {'label': 'Positive', 'score': 0.609040379524231},
#  {'label': 'Negative', 'score': 0.9766729474067688},
#  {'label': 'Positive', 'score': 0.9991928935050964},
#  {'label': 'Negative', 'score': 0.7304955720901489},
#  {'label': 'Positive', 'score': 0.99910968542099},
#  {'label': 'Positive', 'score': 0.9988100528717041},
#  {'label': 'Negative', 'score': 0.9997212290763855},
#  {'label': 'Negative', 'score': 0.9092425107955933},
#  {'label': 'Negative', 'score': 0.999497652053833},
#  {'label': 'Positive', 'score': 0.9993077516555786},
#  {'label': 'Positive', 'score': 0.9983800649642944},
#  {'label': 'Positive', 'score': 0.9996739625930786},
#  {'label': 'Positive', 'score': 0.9959765076637268},
#  {'label': 'Negative', 'score': 0.9989225268363953},
#  {'label': 'Positive', 'score': 0.9535890817642212},
#  {'label': 'Negative', 'score': 0.9908552169799805},
#  {'label': 'Positive', 'score': 0.9983986020088196},
#  {'label': 'Positive', 'score': 0.9307712912559509},
#  {'label': 'Positive', 'score': 0.9985643029212952},
#  {'label': 'Positive', 'score': 0.9996310472488403},
#  {'label': 'Positive', 'score': 0.9979978203773499},
#  {'label': 'Positive', 'score': 0.9943404197692871},
#  {'label': 'Positive', 'score': 0.9972602128982544},
#  {'label': 'Positive', 'score': 0.9176963567733765},
#  {'label': 'Positive', 'score': 0.9993733763694763},
#  {'label': 'Positive', 'score': 0.9995630383491516},
#  {'label': 'Positive', 'score': 0.9992086291313171},
#  {'label': 'Positive', 'score': 0.5878063440322876},
#  {'label': 'Positive', 'score': 0.9990304708480835},
#  {'label': 'Positive', 'score': 0.9859349727630615},
#  {'label': 'Positive', 'score': 0.994082510471344},
#  {'label': 'Negative', 'score': 0.9589318037033081},
#  {'label': 'Negative', 'score': 0.9991976618766785},
#  {'label': 'Negative', 'score': 0.9925622344017029},
#  {'label': 'Negative', 'score': 0.9982019662857056},
#  {'label': 'Negative', 'score': 0.9985076785087585},
#  {'label': 'Positive', 'score': 0.9963690042495728},
#  {'label': 'Positive', 'score': 0.9996869564056396},
#  {'label': 'Positive', 'score': 0.7044514417648315},
#  {'label': 'Negative', 'score': 0.6874791383743286},
#  {'label': 'Positive', 'score': 0.9973292350769043},
#  {'label': 'Positive', 'score': 0.986315906047821},
#  {'label': 'Positive', 'score': 0.9988576173782349},
#  {'label': 'Negative', 'score': 0.9984097480773926},
#  {'label': 'Positive', 'score': 0.9990487694740295},
#  {'label': 'Positive', 'score': 0.9993876218795776},
#  {'label': 'Positive', 'score': 0.9987967014312744},
#  {'label': 'Negative', 'score': 0.5402058959007263},
#  {'label': 'Negative', 'score': 0.9983876943588257},
#  {'label': 'Positive', 'score': 0.9687730669975281},
#  {'label': 'Positive', 'score': 0.9920222759246826},
#  {'label': 'Positive', 'score': 0.9878217577934265},
#  {'label': 'Positive', 'score': 0.8486641645431519},
#  {'label': 'Negative', 'score': 0.9992592930793762},
#  {'label': 'Negative', 'score': 0.9995854496955872},
#  {'label': 'Positive', 'score': 0.9968401193618774},
#  {'label': 'Positive', 'score': 0.9977279305458069},
#  {'label': 'Positive', 'score': 0.9985194802284241},
#  {'label': 'Negative', 'score': 0.992901086807251},
#  {'label': 'Negative', 'score': 0.9962136149406433},
#  {'label': 'Positive', 'score': 0.808867871761322},
#  {'label': 'Negative', 'score': 0.9843296408653259},
#  {'label': 'Positive', 'score': 0.9974933862686157},
#  {'label': 'Positive', 'score': 0.8502804040908813},
#  {'label': 'Positive', 'score': 0.9814334511756897},
#  {'label': 'Positive', 'score': 0.9944753050804138},
#  {'label': 'Positive', 'score': 0.9996205568313599},
#  {'label': 'Positive', 'score': 0.9978252649307251},
#  {'label': 'Positive', 'score': 0.9995478987693787},
#  {'label': 'Negative', 'score': 0.9822884798049927},
#  {'label': 'Negative', 'score': 0.915311336517334},
#  {'label': 'Positive', 'score': 0.876298725605011},
#  {'label': 'Positive', 'score': 0.8261524438858032},
#  {'label': 'Positive', 'score': 0.9884065985679626},
#  {'label': 'Positive', 'score': 0.9580949544906616},
#  {'label': 'Positive', 'score': 0.9994112253189087},
#  {'label': 'Positive', 'score': 0.9968063831329346},
#  {'label': 'Positive', 'score': 0.9104809761047363},
#  {'label': 'Negative', 'score': 0.6310072541236877},
#  {'label': 'Negative', 'score': 0.9977892637252808},
#  {'label': 'Negative', 'score': 0.9812139272689819},
#  {'label': 'Positive', 'score': 0.9961477518081665},
#  {'label': 'Negative', 'score': 0.7305166125297546},
#  {'label': 'Positive', 'score': 0.9994246959686279},
#  {'label': 'Positive', 'score': 0.9995057582855225},
#  {'label': 'Positive', 'score': 0.7858622670173645},
#  {'label': 'Positive', 'score': 0.986927330493927},
#  {'label': 'Positive', 'score': 0.9989466071128845},
#  {'label': 'Positive', 'score': 0.9995631575584412},
#  {'label': 'Positive', 'score': 0.9992032647132874},
#  {'label': 'Positive', 'score': 0.9991034865379333},
#  {'label': 'Positive', 'score': 0.9993221759796143},
#  {'label': 'Positive', 'score': 0.9995973706245422},
#  {'label': 'Positive', 'score': 0.999032735824585},
#  {'label': 'Positive', 'score': 0.9887416958808899},
#  {'label': 'Positive', 'score': 0.9296544790267944},
#  {'label': 'Positive', 'score': 0.9883376955986023},
#  {'label': 'Positive', 'score': 0.9988528490066528},
#  {'label': 'Positive', 'score': 0.9987524747848511},
#  {'label': 'Negative', 'score': 0.9952874183654785},
#  {'label': 'Positive', 'score': 0.9471409916877747},
#  {'label': 'Positive', 'score': 0.9949855804443359},
#  {'label': 'Negative', 'score': 0.9779970049858093},
#  {'label': 'Positive', 'score': 0.9992347955703735},
#  {'label': 'Positive', 'score': 0.9982531666755676},
#  {'label': 'Positive', 'score': 0.9813287258148193},
#  {'label': 'Positive', 'score': 0.9937177896499634},
#  {'label': 'Negative', 'score': 0.9082459807395935},
#  {'label': 'Positive', 'score': 0.9945818781852722},
#  {'label': 'Positive', 'score': 0.9957667589187622},
#  {'label': 'Positive', 'score': 0.9990934133529663},
#  {'label': 'Negative', 'score': 0.999455988407135},
#  {'label': 'Positive', 'score': 0.9753561615943909},
#  {'label': 'Positive', 'score': 0.989827036857605},
#  {'label': 'Negative', 'score': 0.9927049279212952},
#  {'label': 'Positive', 'score': 0.98337721824646},
#  {'label': 'Positive', 'score': 0.99913090467453},
#  {'label': 'Negative', 'score': 0.9995346069335938},
#  {'label': 'Negative', 'score': 0.9997690320014954},
#  {'label': 'Positive', 'score': 0.9926140308380127},
#  {'label': 'Positive', 'score': 0.863772451877594},
#  {'label': 'Positive', 'score': 0.9973440766334534},
#  {'label': 'Positive', 'score': 0.9994856119155884},
#  {'label': 'Positive', 'score': 0.9995904564857483},
#  {'label': 'Positive', 'score': 0.9996721744537354},
#  {'label': 'Positive', 'score': 0.9878751635551453},
#  {'label': 'Positive', 'score': 0.9996839761734009},
#  {'label': 'Positive', 'score': 0.9958856701850891},
#  {'label': 'Positive', 'score': 0.9994475245475769},
#  {'label': 'Positive', 'score': 0.9540324807167053},
#  {'label': 'Positive', 'score': 0.9969395399093628},
#  {'label': 'Positive', 'score': 0.9929138422012329},
#  {'label': 'Negative', 'score': 0.984459400177002},
#  {'label': 'Positive', 'score': 0.9935897588729858},
#  {'label': 'Positive', 'score': 0.9579660892486572},
#  {'label': 'Positive', 'score': 0.9994370341300964},
#  {'label': 'Negative', 'score': 0.9993119239807129},
#  {'label': 'Negative', 'score': 0.9989802241325378},
#  {'label': 'Positive', 'score': 0.9951727986335754},
#  {'label': 'Positive', 'score': 0.9995755553245544},
#  {'label': 'Positive', 'score': 0.999051034450531},
#  {'label': 'Positive', 'score': 0.9780925512313843},
#  {'label': 'Positive', 'score': 0.9842556118965149},
#  {'label': 'Negative', 'score': 0.9829381108283997},
#  {'label': 'Positive', 'score': 0.9219722747802734},
#  {'label': 'Positive', 'score': 0.5275084972381592},
#  {'label': 'Positive', 'score': 0.9961471557617188},
#  {'label': 'Negative', 'score': 0.9659152626991272},
#  {'label': 'Positive', 'score': 0.9986311793327332},
#  {'label': 'Positive', 'score': 0.9996917247772217},
#  {'label': 'Positive', 'score': 0.9995335340499878},
#  {'label': 'Positive', 'score': 0.997820258140564},
#  {'label': 'Negative', 'score': 0.9807891249656677},
#  {'label': 'Positive', 'score': 0.9958386421203613},
#  {'label': 'Positive', 'score': 0.9996102452278137},
#  {'label': 'Positive', 'score': 0.9983580708503723},
#  {'label': 'Positive', 'score': 0.9925162196159363},
#  {'label': 'Positive', 'score': 0.79050612449646},
#  {'label': 'Positive', 'score': 0.9995380640029907},
#  {'label': 'Positive', 'score': 0.9969160556793213},
#  {'label': 'Positive', 'score': 0.9982091188430786},
#  {'label': 'Positive', 'score': 0.5355097651481628},
#  {'label': 'Positive', 'score': 0.9991363883018494},
#  {'label': 'Positive', 'score': 0.9851497411727905},
#  {'label': 'Positive', 'score': 0.9958670139312744},
#  {'label': 'Positive', 'score': 0.9960224628448486},
#  {'label': 'Positive', 'score': 0.9995112419128418},
#  {'label': 'Positive', 'score': 0.9993036985397339},
#  {'label': 'Positive', 'score': 0.9786407351493835},
#  {'label': 'Positive', 'score': 0.9536524415016174},
#  {'label': 'Negative', 'score': 0.9990692734718323},
#  {'label': 'Positive', 'score': 0.9962305426597595},
#  {'label': 'Negative', 'score': 0.6985605359077454},
#  {'label': 'Negative', 'score': 0.9236278533935547},
#  {'label': 'Positive', 'score': 0.998824417591095},
#  {'label': 'Negative', 'score': 0.5237491130828857},
#  {'label': 'Negative', 'score': 0.9993939399719238},
#  {'label': 'Positive', 'score': 0.9952753782272339},
#  {'label': 'Positive', 'score': 0.9968709349632263},
#  {'label': 'Negative', 'score': 0.9403722882270813},
#  {'label': 'Negative', 'score': 0.9989247918128967},
#  {'label': 'Positive', 'score': 0.9994377493858337},
#  {'label': 'Positive', 'score': 0.9990450739860535},
#  {'label': 'Negative', 'score': 0.9772862792015076},
#  {'label': 'Negative', 'score': 0.9751186370849609},
#  {'label': 'Negative', 'score': 0.9996125102043152},
#  {'label': 'Negative', 'score': 0.9931337833404541},
#  {'label': 'Positive', 'score': 0.9890128374099731},
#  {'label': 'Positive', 'score': 0.999029278755188},
#  {'label': 'Negative', 'score': 0.9744313955307007},
#  {'label': 'Negative', 'score': 0.9967052340507507},
#  {'label': 'Positive', 'score': 0.6211133003234863},
#  {'label': 'Positive', 'score': 0.9952027797698975},
#  {'label': 'Positive', 'score': 0.8970291018486023},
#  {'label': 'Positive', 'score': 0.9434489011764526},
#  {'label': 'Positive', 'score': 0.9996401071548462},
#  {'label': 'Negative', 'score': 0.9974895715713501},
#  {'label': 'Positive', 'score': 0.9994590878486633},
#  {'label': 'Negative', 'score': 0.9996531009674072},
#  {'label': 'Negative', 'score': 0.8292102813720703},
#  {'label': 'Positive', 'score': 0.8991509675979614},
#  {'label': 'Negative', 'score': 0.9978710412979126},
#  {'label': 'Positive', 'score': 0.9992837309837341},
#  {'label': 'Positive', 'score': 0.9992265701293945},
#  {'label': 'Positive', 'score': 0.9433079957962036},
#  {'label': 'Positive', 'score': 0.9724407196044922},
#  {'label': 'Negative', 'score': 0.9838948845863342},
#  {'label': 'Negative', 'score': 0.9995168447494507},
#  {'label': 'Negative', 'score': 0.999600350856781},
#  {'label': 'Negative', 'score': 0.6521780490875244},
#  {'label': 'Negative', 'score': 0.9997517466545105},
#  {'label': 'Positive', 'score': 0.7320799231529236},
#  {'label': 'Negative', 'score': 0.9980827569961548},
#  {'label': 'Negative', 'score': 0.9622198939323425},
#  {'label': 'Negative', 'score': 0.9853691458702087},
#  {'label': 'Positive', 'score': 0.9559153914451599},
#  {'label': 'Positive', 'score': 0.9764129519462585},
#  {'label': 'Positive', 'score': 0.9940432906150818},
#  {'label': 'Positive', 'score': 0.9982158541679382},
#  {'label': 'Negative', 'score': 0.9996863603591919},
#  {'label': 'Negative', 'score': 0.9947636127471924},
#  {'label': 'Negative', 'score': 0.9870496392250061},
#  {'label': 'Negative', 'score': 0.963763952255249},
#  {'label': 'Negative', 'score': 0.9822906851768494},
#  {'label': 'Positive', 'score': 0.9993926286697388},
#  {'label': 'Positive', 'score': 0.9995601773262024},
#  {'label': 'Positive', 'score': 0.9996435642242432},
#  {'label': 'Positive', 'score': 0.9987616539001465},
#  {'label': 'Positive', 'score': 0.9995465874671936},
#  {'label': 'Positive', 'score': 0.9996901750564575},
#  {'label': 'Positive', 'score': 0.9926089644432068},
#  {'label': 'Positive', 'score': 0.99925297498703},
#  {'label': 'Positive', 'score': 0.9827249646186829},
#  {'label': 'Positive', 'score': 0.9988478422164917},
#  {'label': 'Positive', 'score': 0.9846606850624084},
#  {'label': 'Positive', 'score': 0.9988478422164917},
#  {'label': 'Positive', 'score': 0.9971725940704346},
#  {'label': 'Positive', 'score': 0.997471809387207},
#  {'label': 'Positive', 'score': 0.9869306087493896},
#  {'label': 'Positive', 'score': 0.867006242275238},
#  {'label': 'Positive', 'score': 0.9953990578651428},
#  {'label': 'Positive', 'score': 0.989829957485199},
#  {'label': 'Positive', 'score': 0.9941180944442749},
#  {'label': 'Positive', 'score': 0.9791231155395508},
#  {'label': 'Positive', 'score': 0.9755412340164185},
#  {'label': 'Positive', 'score': 0.9991205334663391},
#  {'label': 'Positive', 'score': 0.9945493340492249},
#  {'label': 'Positive', 'score': 0.9996243715286255},
#  {'label': 'Positive', 'score': 0.9994416832923889},
#  {'label': 'Positive', 'score': 0.9593889117240906},
#  {'label': 'Positive', 'score': 0.9890967011451721},
#  {'label': 'Positive', 'score': 0.9911942481994629},
#  {'label': 'Positive', 'score': 0.9974141120910645},
#  {'label': 'Negative', 'score': 0.9804598093032837},
#  {'label': 'Positive', 'score': 0.9963417649269104},
#  {'label': 'Positive', 'score': 0.6683251857757568},
#  {'label': 'Positive', 'score': 0.9956501126289368},
#  {'label': 'Positive', 'score': 0.7978627681732178},
#  {'label': 'Positive', 'score': 0.9994243383407593},
#  {'label': 'Positive', 'score': 0.9995535016059875},
#  {'label': 'Positive', 'score': 0.9985713958740234},
#  {'label': 'Positive', 'score': 0.9981789588928223},
#  {'label': 'Positive', 'score': 0.998213529586792},
#  {'label': 'Positive', 'score': 0.9971669316291809},
#  {'label': 'Negative', 'score': 0.9986883997917175},
#  {'label': 'Negative', 'score': 0.9576586484909058},
#  {'label': 'Negative', 'score': 0.999795138835907},
#  {'label': 'Negative', 'score': 0.9663336277008057},
#  {'label': 'Positive', 'score': 0.9994687438011169},
#  {'label': 'Positive', 'score': 0.7263980507850647},
#  {'label': 'Positive', 'score': 0.9993292093276978},
#  {'label': 'Positive', 'score': 0.8899804949760437},
#  {'label': 'Negative', 'score': 0.9993008375167847},
#  {'label': 'Positive', 'score': 0.9901636242866516},
#  {'label': 'Positive', 'score': 0.9931384921073914},
#  {'label': 'Positive', 'score': 0.999524712562561},
#  {'label': 'Positive', 'score': 0.9971097111701965},
#  {'label': 'Positive', 'score': 0.9930919408798218},
#  {'label': 'Positive', 'score': 0.9072914719581604},
#  {'label': 'Positive', 'score': 0.9906185269355774},
#  {'label': 'Positive', 'score': 0.9263284206390381},
#  {'label': 'Positive', 'score': 0.9994660019874573},
#  {'label': 'Positive', 'score': 0.9993345141410828},
#  {'label': 'Positive', 'score': 0.9996053576469421},
#  {'label': 'Positive', 'score': 0.998038113117218},
#  {'label': 'Positive', 'score': 0.9841600060462952},
#  {'label': 'Positive', 'score': 0.999562680721283},
#  {'label': 'Positive', 'score': 0.9899402260780334},
#  {'label': 'Negative', 'score': 0.9734753966331482},
#  {'label': 'Negative', 'score': 0.9978885054588318},
#  {'label': 'Negative', 'score': 0.9645358920097351},
#  {'label': 'Negative', 'score': 0.9996071457862854},
#  {'label': 'Positive', 'score': 0.9848426580429077},
#  {'label': 'Negative', 'score': 0.9988555908203125},
#  {'label': 'Negative', 'score': 0.9990712404251099},
#  {'label': 'Positive', 'score': 0.9989515542984009},
#  {'label': 'Positive', 'score': 0.9916139841079712},
#  {'label': 'Positive', 'score': 0.9992212057113647},
#  {'label': 'Positive', 'score': 0.9984493255615234},
#  {'label': 'Negative', 'score': 0.5619137287139893},
#  {'label': 'Positive', 'score': 0.9929239749908447},
#  {'label': 'Positive', 'score': 0.9967554211616516},
#  {'label': 'Positive', 'score': 0.6283809542655945},
#  {'label': 'Positive', 'score': 0.7742589712142944},
#  {'label': 'Positive', 'score': 0.999277651309967},
#  {'label': 'Negative', 'score': 0.999704897403717},
#  {'label': 'Negative', 'score': 0.9814136028289795},
#  {'label': 'Negative', 'score': 0.9997321963310242},
#  {'label': 'Positive', 'score': 0.9883443117141724},
#  {'label': 'Positive', 'score': 0.9973528385162354},
#  {'label': 'Positive', 'score': 0.8892202973365784},
#  {'label': 'Positive', 'score': 0.9991494417190552},
#  {'label': 'Positive', 'score': 0.9995744824409485},
#  {'label': 'Negative', 'score': 0.8547002077102661},
#  {'label': 'Positive', 'score': 0.98440021276474},
#  {'label': 'Positive', 'score': 0.9992181062698364},
#  {'label': 'Positive', 'score': 0.9989571571350098},
#  {'label': 'Positive', 'score': 0.9996627569198608},
#  {'label': 'Positive', 'score': 0.999614953994751},
#  {'label': 'Negative', 'score': 0.9996943473815918},
#  {'label': 'Positive', 'score': 0.9997010231018066},
#  {'label': 'Positive', 'score': 0.9966176152229309},
#  {'label': 'Positive', 'score': 0.9995792508125305},
#  {'label': 'Positive', 'score': 0.998207688331604},
#  {'label': 'Positive', 'score': 0.9996320009231567},
#  {'label': 'Positive', 'score': 0.9997013211250305},
#  {'label': 'Negative', 'score': 0.8258607387542725},
#  {'label': 'Negative', 'score': 0.8493838310241699},
#  {'label': 'Negative', 'score': 0.9992627501487732},
#  {'label': 'Positive', 'score': 0.9995225667953491},
#  {'label': 'Negative', 'score': 0.9993689656257629},
#  {'label': 'Positive', 'score': 0.9957786798477173},
#  {'label': 'Positive', 'score': 0.9983856678009033},
#  {'label': 'Positive', 'score': 0.9985520243644714},
#  {'label': 'Positive', 'score': 0.9957642555236816},
#  {'label': 'Positive', 'score': 0.9995144605636597},
#  {'label': 'Positive', 'score': 0.9919217824935913},
#  {'label': 'Positive', 'score': 0.9956045150756836},
#  {'label': 'Positive', 'score': 0.9829199910163879},
#  {'label': 'Negative', 'score': 0.996362030506134},
#  {'label': 'Positive', 'score': 0.9983727335929871},
#  {'label': 'Positive', 'score': 0.9876930117607117},
#  {'label': 'Positive', 'score': 0.9994751811027527},
#  {'label': 'Positive', 'score': 0.9962441921234131},
#  {'label': 'Positive', 'score': 0.99687659740448},
#  {'label': 'Positive', 'score': 0.9986339211463928},
#  {'label': 'Negative', 'score': 0.8722155690193176},
#  {'label': 'Negative', 'score': 0.9998219609260559},
#  {'label': 'Negative', 'score': 0.9858879446983337},
#  {'label': 'Positive', 'score': 0.999311089515686},
#  {'label': 'Positive', 'score': 0.9951788187026978},
#  {'label': 'Positive', 'score': 0.9901482462882996},
#  {'label': 'Positive', 'score': 0.8789297938346863},
#  {'label': 'Positive', 'score': 0.9989092350006104},
#  {'label': 'Positive', 'score': 0.9994542002677917},
#  {'label': 'Positive', 'score': 0.8962633013725281},
#  {'label': 'Negative', 'score': 0.9957239627838135},
#  {'label': 'Positive', 'score': 0.9996465444564819},
#  {'label': 'Positive', 'score': 0.9610318541526794},
#  {'label': 'Positive', 'score': 0.9960804581642151},
#  {'label': 'Negative', 'score': 0.9913848638534546},
#  {'label': 'Positive', 'score': 0.9778944253921509},
#  {'label': 'Positive', 'score': 0.9992490410804749},
#  {'label': 'Positive', 'score': 0.9960877895355225},
#  {'label': 'Positive', 'score': 0.9962297081947327},
#  {'label': 'Positive', 'score': 0.9167924523353577},
#  {'label': 'Positive', 'score': 0.9812635183334351},
#  {'label': 'Positive', 'score': 0.9965749382972717},
#  {'label': 'Positive', 'score': 0.9733812212944031},
#  {'label': 'Negative', 'score': 0.9997289776802063},
#  {'label': 'Negative', 'score': 0.9887511134147644},
#  {'label': 'Negative', 'score': 0.9994521737098694},
#  {'label': 'Negative', 'score': 0.9413658380508423},
#  {'label': 'Negative', 'score': 0.9992530941963196},
#  {'label': 'Positive', 'score': 0.9073416590690613},
#  {'label': 'Negative', 'score': 0.9976517558097839},
#  {'label': 'Negative', 'score': 0.6502187848091125},
#  {'label': 'Positive', 'score': 0.7659017443656921},
#  {'label': 'Positive', 'score': 0.6440026164054871},
#  {'label': 'Positive', 'score': 0.9002384543418884},
#  {'label': 'Positive', 'score': 0.9970890879631042},
#  {'label': 'Negative', 'score': 0.9991710186004639},
#  {'label': 'Negative', 'score': 0.9995966553688049},
#  {'label': 'Positive', 'score': 0.5757126212120056},
#  {'label': 'Negative', 'score': 0.999240517616272},
#  {'label': 'Positive', 'score': 0.9965071082115173},
#  {'label': 'Positive', 'score': 0.9899351000785828},
#  {'label': 'Positive', 'score': 0.890763521194458},
#  {'label': 'Negative', 'score': 0.9845873117446899},
#  {'label': 'Positive', 'score': 0.966447651386261},
#  {'label': 'Negative', 'score': 0.9983628392219543},
#  {'label': 'Positive', 'score': 0.9987286925315857},
#  {'label': 'Positive', 'score': 0.9771236777305603},
#  {'label': 'Positive', 'score': 0.9481638073921204},
#  {'label': 'Negative', 'score': 0.9990743398666382},
#  {'label': 'Positive', 'score': 0.9993675351142883},
#  {'label': 'Negative', 'score': 0.9872408509254456},
#  {'label': 'Negative', 'score': 0.9838899374008179},
#  {'label': 'Positive', 'score': 0.9678442478179932},
#  {'label': 'Negative', 'score': 0.9995594620704651},
#  {'label': 'Positive', 'score': 0.9643486142158508},
#  {'label': 'Negative', 'score': 0.8833989500999451},
#  {'label': 'Positive', 'score': 0.9988495111465454},
#  {'label': 'Negative', 'score': 0.9942560791969299},
#  {'label': 'Positive', 'score': 0.7597843408584595},
#  {'label': 'Positive', 'score': 0.9958712458610535},
#  {'label': 'Positive', 'score': 0.996629536151886},
#  {'label': 'Positive', 'score': 0.9994747042655945},
#  {'label': 'Positive', 'score': 0.9996046423912048},
#  {'label': 'Positive', 'score': 0.9986956715583801},
#  {'label': 'Positive', 'score': 0.9922188520431519},
#  {'label': 'Positive', 'score': 0.998257577419281},
#  {'label': 'Positive', 'score': 0.9755227565765381},
#  {'label': 'Positive', 'score': 0.9996370077133179},
#  {'label': 'Positive', 'score': 0.9922274351119995},
#  {'label': 'Positive', 'score': 0.9940105080604553},
#  {'label': 'Negative', 'score': 0.971577525138855},
#  {'label': 'Negative', 'score': 0.9983516931533813},
#  {'label': 'Negative', 'score': 0.8544238805770874},
#  {'label': 'Positive', 'score': 0.9986526966094971},
#  {'label': 'Positive', 'score': 0.999477207660675},
#  {'label': 'Positive', 'score': 0.9995037317276001},
#  {'label': 'Positive', 'score': 0.9202346801757812},
#  {'label': 'Positive', 'score': 0.9991229176521301},
#  {'label': 'Negative', 'score': 0.9987754225730896},
#  {'label': 'Positive', 'score': 0.996547281742096},
#  {'label': 'Negative', 'score': 0.9987016916275024},
#  {'label': 'Negative', 'score': 0.7131922841072083},
#  {'label': 'Positive', 'score': 0.9838206768035889},
#  {'label': 'Positive', 'score': 0.9966973066329956},
#  {'label': 'Negative', 'score': 0.9995754361152649},
#  {'label': 'Positive', 'score': 0.6133276224136353},
#  {'label': 'Positive', 'score': 0.9885440468788147},
#  {'label': 'Negative', 'score': 0.9996645450592041},
#  {'label': 'Negative', 'score': 0.9592450857162476},
#  {'label': 'Negative', 'score': 0.9983993172645569},
#  {'label': 'Positive', 'score': 0.9995136260986328},
#  {'label': 'Positive', 'score': 0.9988535642623901},
#  {'label': 'Positive', 'score': 0.999574601650238},
#  {'label': 'Negative', 'score': 0.9995850920677185},
#  {'label': 'Positive', 'score': 0.9979255199432373},
#  {'label': 'Positive', 'score': 0.9898776412010193},
#  {'label': 'Positive', 'score': 0.9980814456939697},
#  {'label': 'Negative', 'score': 0.9993740916252136},
#  {'label': 'Positive', 'score': 0.9983999133110046},
#  {'label': 'Positive', 'score': 0.9993627667427063},
#  {'label': 'Positive', 'score': 0.9945799112319946},
#  {'label': 'Positive', 'score': 0.9664313793182373},
#  {'label': 'Positive', 'score': 0.8691719770431519},
#  {'label': 'Positive', 'score': 0.9774163961410522},
#  {'label': 'Positive', 'score': 0.9879381060600281},
#  {'label': 'Positive', 'score': 0.8041648864746094},
#  {'label': 'Positive', 'score': 0.9879915118217468},
#  {'label': 'Positive', 'score': 0.995274543762207},
#  {'label': 'Negative', 'score': 0.9960442781448364},
#  {'label': 'Positive', 'score': 0.9944151639938354},
#  {'label': 'Positive', 'score': 0.8654623627662659},
#  {'label': 'Positive', 'score': 0.9528042674064636},
#  {'label': 'Negative', 'score': 0.9993738532066345},
#  {'label': 'Positive', 'score': 0.9079710245132446},
#  {'label': 'Negative', 'score': 0.9907591342926025},
#  {'label': 'Negative', 'score': 0.9985653758049011},
#  {'label': 'Positive', 'score': 0.9931835532188416},
#  {'label': 'Positive', 'score': 0.9949133396148682},
#  {'label': 'Positive', 'score': 0.9944362640380859},
#  {'label': 'Positive', 'score': 0.999579131603241},
#  {'label': 'Positive', 'score': 0.9973662495613098},
#  {'label': 'Negative', 'score': 0.8186538219451904},
#  {'label': 'Negative', 'score': 0.9994506239891052},
#  {'label': 'Positive', 'score': 0.9996857643127441},
#  {'label': 'Positive', 'score': 0.9990290403366089},
#  {'label': 'Negative', 'score': 0.9891017079353333},
#  {'label': 'Negative', 'score': 0.9988634586334229},
#  {'label': 'Positive', 'score': 0.9993000030517578},
#  {'label': 'Positive', 'score': 0.9936050772666931},
#  {'label': 'Positive', 'score': 0.9995005130767822},
#  {'label': 'Positive', 'score': 0.9995014667510986},
#  {'label': 'Positive', 'score': 0.9552753567695618},
#  {'label': 'Negative', 'score': 0.9996722936630249},
#  {'label': 'Positive', 'score': 0.9707130193710327},
#  {'label': 'Positive', 'score': 0.9587737917900085},
#  {'label': 'Positive', 'score': 0.8650211095809937},
#  {'label': 'Positive', 'score': 0.9936002492904663},
#  {'label': 'Positive', 'score': 0.9961047172546387},
#  {'label': 'Negative', 'score': 0.9926673769950867},
#  {'label': 'Positive', 'score': 0.9460873007774353},
#  {'label': 'Positive', 'score': 0.9849039316177368},
#  {'label': 'Negative', 'score': 0.9989181756973267},
#  {'label': 'Positive', 'score': 0.9846478700637817},
#  {'label': 'Positive', 'score': 0.9995162487030029},
#  {'label': 'Positive', 'score': 0.9991236329078674},
#  {'label': 'Negative', 'score': 0.9990204572677612},
#  {'label': 'Negative', 'score': 0.999733030796051},
#  {'label': 'Negative', 'score': 0.9719346761703491},
#  {'label': 'Positive', 'score': 0.9990431666374207},
#  {'label': 'Positive', 'score': 0.9680542349815369},
#  {'label': 'Positive', 'score': 0.9435655474662781},
#  {'label': 'Positive', 'score': 0.9970343112945557},
#  {'label': 'Positive', 'score': 0.9883055686950684},
#  {'label': 'Positive', 'score': 0.9969340562820435},
#  {'label': 'Negative', 'score': 0.9983853101730347},
#  {'label': 'Positive', 'score': 0.9990192651748657},
#  {'label': 'Positive', 'score': 0.9985015392303467},
#  {'label': 'Negative', 'score': 0.6931006908416748},
#  {'label': 'Positive', 'score': 0.9995131492614746},
#  {'label': 'Positive', 'score': 0.973116397857666},
#  {'label': 'Positive', 'score': 0.9996100068092346},
#  {'label': 'Positive', 'score': 0.8680043816566467},
#  {'label': 'Positive', 'score': 0.9994122982025146},
#  {'label': 'Negative', 'score': 0.9963966012001038},
#  {'label': 'Negative', 'score': 0.998344898223877},
#  {'label': 'Positive', 'score': 0.9759001135826111},
#  {'label': 'Negative', 'score': 0.9994773268699646},
#  {'label': 'Negative', 'score': 0.5045492053031921},
#  {'label': 'Negative', 'score': 0.9438610076904297},
#  {'label': 'Negative', 'score': 0.9129541516304016},
#  {'label': 'Positive', 'score': 0.9995042085647583},
#  {'label': 'Negative', 'score': 0.9993463158607483},
#  {'label': 'Negative', 'score': 0.96189945936203},
#  {'label': 'Positive', 'score': 0.5459746718406677},
#  {'label': 'Positive', 'score': 0.9897491335868835},
#  {'label': 'Negative', 'score': 0.8060224652290344},
#  {'label': 'Positive', 'score': 0.9863102436065674},
#  {'label': 'Positive', 'score': 0.9994818568229675},
#  {'label': 'Positive', 'score': 0.9967856407165527},
#  {'label': 'Positive', 'score': 0.9971117973327637},
#  {'label': 'Positive', 'score': 0.9995737671852112},
#  {'label': 'Positive', 'score': 0.9973742961883545},
#  {'label': 'Negative', 'score': 0.9298016428947449},
#  {'label': 'Negative', 'score': 0.9905152320861816},
#  {'label': 'Negative', 'score': 0.5360651612281799},
#  {'label': 'Positive', 'score': 0.9994086027145386},
#  {'label': 'Positive', 'score': 0.8207465410232544},
#  {'label': 'Positive', 'score': 0.9995263814926147},
#  {'label': 'Negative', 'score': 0.8846431970596313},
#  {'label': 'Positive', 'score': 0.7294908761978149},
#  {'label': 'Positive', 'score': 0.9988433122634888},
#  {'label': 'Positive', 'score': 0.9817736744880676},
#  {'label': 'Negative', 'score': 0.9944262504577637},
#  {'label': 'Positive', 'score': 0.9995926022529602},
#  {'label': 'Negative', 'score': 0.995686411857605},
#  {'label': 'Positive', 'score': 0.9725348353385925},
#  {'label': 'Negative', 'score': 0.99870765209198},
#  {'label': 'Positive', 'score': 0.9968370199203491},
#  {'label': 'Positive', 'score': 0.989678144454956},
#  {'label': 'Positive', 'score': 0.9903304576873779},
#  {'label': 'Positive', 'score': 0.6915174126625061},
#  {'label': 'Positive', 'score': 0.9407554268836975},
#  {'label': 'Positive', 'score': 0.8864260911941528},
#  {'label': 'Positive', 'score': 0.8730640411376953},
#  {'label': 'Positive', 'score': 0.999201238155365},
#  {'label': 'Positive', 'score': 0.9967848062515259},
#  {'label': 'Negative', 'score': 0.9884659051895142},
#  {'label': 'Negative', 'score': 0.9996252059936523},
#  {'label': 'Positive', 'score': 0.9989080429077148},
#  {'label': 'Positive', 'score': 0.996709942817688},
#  {'label': 'Positive', 'score': 0.9974532723426819},
#  {'label': 'Positive', 'score': 0.7235526442527771},
#  {'label': 'Positive', 'score': 0.9948004484176636},
#  {'label': 'Negative', 'score': 0.9997339844703674},
#  {'label': 'Negative', 'score': 0.9949519634246826},
#  {'label': 'Negative', 'score': 0.5743812918663025},
#  {'label': 'Negative', 'score': 0.9413819313049316},
#  {'label': 'Positive', 'score': 0.99604731798172},
#  {'label': 'Positive', 'score': 0.9958192110061646},
#  {'label': 'Negative', 'score': 0.9501476883888245},
#  {'label': 'Positive', 'score': 0.8756129741668701},
#  {'label': 'Positive', 'score': 0.976718008518219},
#  {'label': 'Positive', 'score': 0.9791172742843628},
#  {'label': 'Positive', 'score': 0.9974195957183838},
#  {'label': 'Positive', 'score': 0.9991816878318787},
#  {'label': 'Positive', 'score': 0.9995532631874084},
#  {'label': 'Positive', 'score': 0.9961168766021729},
#  {'label': 'Negative', 'score': 0.9780651926994324},
#  {'label': 'Negative', 'score': 0.9995903372764587},
#  {'label': 'Negative', 'score': 0.9974763989448547},
#  {'label': 'Negative', 'score': 0.9997361302375793},
#  {'label': 'Positive', 'score': 0.9889928698539734},
#  {'label': 'Positive', 'score': 0.9982197880744934},
#  {'label': 'Negative', 'score': 0.9885651469230652},
#  {'label': 'Positive', 'score': 0.9930364489555359},
#  {'label': 'Positive', 'score': 0.9967063069343567},
#  {'label': 'Positive', 'score': 0.9993313550949097},
#  {'label': 'Negative', 'score': 0.9988466501235962},
#  {'label': 'Positive', 'score': 0.9381669759750366},
#  {'label': 'Negative', 'score': 0.9993759989738464},
#  {'label': 'Negative', 'score': 0.9974989295005798},
#  {'label': 'Positive', 'score': 0.8635144233703613},
#  {'label': 'Positive', 'score': 0.988215446472168},
#  {'label': 'Negative', 'score': 0.9994159936904907},
#  {'label': 'Negative', 'score': 0.9973680377006531},
#  {'label': 'Negative', 'score': 0.5857500433921814},
#  {'label': 'Negative', 'score': 0.947528600692749},
#  {'label': 'Positive', 'score': 0.8905130624771118},
#  {'label': 'Negative', 'score': 0.7246142029762268},
#  {'label': 'Negative', 'score': 0.9994726777076721},
#  {'label': 'Positive', 'score': 0.9948381781578064},
#  {'label': 'Positive', 'score': 0.9918826222419739},
#  {'label': 'Negative', 'score': 0.956304132938385},
#  {'label': 'Positive', 'score': 0.9982221722602844},
#  {'label': 'Negative', 'score': 0.5025122165679932},
#  {'label': 'Positive', 'score': 0.9982908368110657},
#  {'label': 'Positive', 'score': 0.9961246848106384},
#  {'label': 'Positive', 'score': 0.9969393014907837},
#  {'label': 'Positive', 'score': 0.9963307976722717},
#  {'label': 'Negative', 'score': 0.9993841648101807},
#  {'label': 'Negative', 'score': 0.9993940591812134},
#  {'label': 'Positive', 'score': 0.9548929929733276},
#  {'label': 'Positive', 'score': 0.9612237215042114},
#  {'label': 'Positive', 'score': 0.9982458353042603},
#  {'label': 'Negative', 'score': 0.655392587184906},
#  {'label': 'Negative', 'score': 0.9927652478218079},
#  {'label': 'Negative', 'score': 0.9935898780822754},
#  {'label': 'Negative', 'score': 0.5727498531341553},
#  {'label': 'Positive', 'score': 0.9996250867843628},
#  {'label': 'Negative', 'score': 0.7841230034828186},
#  {'label': 'Positive', 'score': 0.9885146021842957},
#  {'label': 'Positive', 'score': 0.9986758828163147},
#  {'label': 'Positive', 'score': 0.993222713470459},
#  {'label': 'Positive', 'score': 0.9622331261634827},
#  {'label': 'Positive', 'score': 0.9989338517189026},
#  {'label': 'Positive', 'score': 0.9989884495735168},
#  {'label': 'Negative', 'score': 0.9978471994400024},
#  {'label': 'Negative', 'score': 0.999447762966156},
#  {'label': 'Positive', 'score': 0.9979460835456848},
#  {'label': 'Negative', 'score': 0.9996883869171143},
#  {'label': 'Negative', 'score': 0.9997791647911072},
#  {'label': 'Negative', 'score': 0.9996979236602783},
#  {'label': 'Negative', 'score': 0.9991288781166077},
#  {'label': 'Negative', 'score': 0.5153000950813293},
#  {'label': 'Positive', 'score': 0.9737793803215027},
#  {'label': 'Positive', 'score': 0.6136944890022278},
#  {'label': 'Positive', 'score': 0.9991017580032349},
#  {'label': 'Positive', 'score': 0.9972857236862183},
#  {'label': 'Negative', 'score': 0.9744971394538879},
#  {'label': 'Positive', 'score': 0.9987704157829285},
#  {'label': 'Positive', 'score': 0.9996570348739624},
#  {'label': 'Negative', 'score': 0.8636302947998047},
#  {'label': 'Negative', 'score': 0.996857762336731},
#  {'label': 'Positive', 'score': 0.9931992888450623},
#  {'label': 'Negative', 'score': 0.9985900521278381},
#  {'label': 'Positive', 'score': 0.9994015693664551},
#  {'label': 'Positive', 'score': 0.9996799230575562},
#  {'label': 'Positive', 'score': 0.9994452595710754},
#  {'label': 'Positive', 'score': 0.99947589635849},
#  {'label': 'Positive', 'score': 0.9996994733810425},
#  {'label': 'Positive', 'score': 0.9959988594055176},
#  {'label': 'Positive', 'score': 0.999600350856781},
#  {'label': 'Positive', 'score': 0.9977669715881348},
#  {'label': 'Positive', 'score': 0.9944455623626709},
#  {'label': 'Positive', 'score': 0.9493195414543152},
#  {'label': 'Positive', 'score': 0.9961214661598206},
#  {'label': 'Positive', 'score': 0.9992026686668396},
#  {'label': 'Positive', 'score': 0.9966064691543579},
#  {'label': 'Positive', 'score': 0.8571624159812927},
#  {'label': 'Positive', 'score': 0.9996304512023926},
#  {'label': 'Positive', 'score': 0.9996262788772583},
#  {'label': 'Negative', 'score': 0.6048664450645447},
#  {'label': 'Negative', 'score': 0.9290018677711487},
#  {'label': 'Negative', 'score': 0.7626460790634155},
#  {'label': 'Negative', 'score': 0.9994921684265137},
#  {'label': 'Negative', 'score': 0.9609714150428772},
#  {'label': 'Negative', 'score': 0.9938649535179138},
#  {'label': 'Positive', 'score': 0.9847010374069214},
#  {'label': 'Positive', 'score': 0.99222731590271},
#  {'label': 'Positive', 'score': 0.9995312690734863},
#  {'label': 'Positive', 'score': 0.9617653489112854},
#  {'label': 'Positive', 'score': 0.8007660508155823},
#  {'label': 'Positive', 'score': 0.8263360857963562},
#  {'label': 'Positive', 'score': 0.930154025554657},
#  {'label': 'Positive', 'score': 0.5577518343925476},
#  {'label': 'Positive', 'score': 0.9684643745422363},
#  {'label': 'Positive', 'score': 0.621255099773407},
#  {'label': 'Positive', 'score': 0.9676969647407532},
#  {'label': 'Positive', 'score': 0.919796347618103},
#  {'label': 'Positive', 'score': 0.8372927308082581},
#  {'label': 'Negative', 'score': 0.8669629096984863},
#  {'label': 'Positive', 'score': 0.9924335479736328},
#  {'label': 'Positive', 'score': 0.9906011819839478},
#  {'label': 'Negative', 'score': 0.9792001843452454},
#  {'label': 'Positive', 'score': 0.9941458702087402},
#  {'label': 'Positive', 'score': 0.9987163543701172},
#  {'label': 'Positive', 'score': 0.9920992851257324},
#  {'label': 'Positive', 'score': 0.9982014894485474},
#  {'label': 'Positive', 'score': 0.9385898113250732},
#  {'label': 'Positive', 'score': 0.9867128133773804},
#  {'label': 'Positive', 'score': 0.9995406866073608},
#  {'label': 'Positive', 'score': 0.9807029962539673},
#  {'label': 'Negative', 'score': 0.6965339779853821},
#  {'label': 'Positive', 'score': 0.9945989847183228},
#  {'label': 'Positive', 'score': 0.9918598532676697},
#  {'label': 'Positive', 'score': 0.9965142607688904},
#  {'label': 'Negative', 'score': 0.7716096639633179},
#  {'label': 'Positive', 'score': 0.9787830114364624},
#  {'label': 'Negative', 'score': 0.9986473917961121},
#  {'label': 'Positive', 'score': 0.9986026883125305},
#  {'label': 'Positive', 'score': 0.9605090022087097},
#  {'label': 'Positive', 'score': 0.9957066178321838},
#  {'label': 'Positive', 'score': 0.9830051064491272},
#  {'label': 'Positive', 'score': 0.9925414323806763},
#  {'label': 'Positive', 'score': 0.9957066178321838},
#  {'label': 'Negative', 'score': 0.8744697570800781},
#  {'label': 'Negative', 'score': 0.6115872859954834},
#  {'label': 'Positive', 'score': 0.9846442937850952},
#  {'label': 'Positive', 'score': 0.9835829138755798},
#  {'label': 'Positive', 'score': 0.9988803267478943},
#  {'label': 'Positive', 'score': 0.7663314938545227},
#  {'label': 'Positive', 'score': 0.7232668399810791},
#  {'label': 'Positive', 'score': 0.9996576309204102},
#  {'label': 'Positive', 'score': 0.999580442905426},
#  {'label': 'Positive', 'score': 0.9992944002151489},
#  {'label': 'Positive', 'score': 0.9978850483894348},
#  {'label': 'Positive', 'score': 0.9991687536239624},
#  {'label': 'Positive', 'score': 0.9993846416473389},
#  {'label': 'Positive', 'score': 0.9729154109954834},
#  {'label': 'Positive', 'score': 0.9886624217033386},
#  {'label': 'Negative', 'score': 0.6008819341659546},
#  {'label': 'Negative', 'score': 0.8480536341667175},
#  {'label': 'Negative', 'score': 0.998490571975708},
#  {'label': 'Negative', 'score': 0.9992361068725586},
#  {'label': 'Positive', 'score': 0.9802950024604797},
#  {'label': 'Negative', 'score': 0.9975683093070984},
#  {'label': 'Positive', 'score': 0.9975499510765076},
#  {'label': 'Positive', 'score': 0.9388200640678406},
#  {'label': 'Positive', 'score': 0.9977447986602783},
#  {'label': 'Positive', 'score': 0.8627621531486511},
#  {'label': 'Positive', 'score': 0.9979039430618286},
#  {'label': 'Negative', 'score': 0.9917369484901428},
#  {'label': 'Negative', 'score': 0.9994155168533325},
#  {'label': 'Positive', 'score': 0.9292526245117188},
#  {'label': 'Positive', 'score': 0.9984342455863953},
#  {'label': 'Negative', 'score': 0.9921988844871521},
#  {'label': 'Negative', 'score': 0.9951381087303162},
#  {'label': 'Positive', 'score': 0.997163712978363},
#  {'label': 'Positive', 'score': 0.9996798038482666},
#  {'label': 'Positive', 'score': 0.9989268183708191},
#  {'label': 'Positive', 'score': 0.9839186668395996},
#  {'label': 'Positive', 'score': 0.9982241988182068},
#  {'label': 'Negative', 'score': 0.9996058344841003},
#  {'label': 'Negative', 'score': 0.9854527115821838},
#  {'label': 'Positive', 'score': 0.996684730052948},
#  {'label': 'Positive', 'score': 0.8665496706962585},
#  {'label': 'Positive', 'score': 0.9994787573814392},
#  {'label': 'Negative', 'score': 0.9996402263641357},
#  {'label': 'Positive', 'score': 0.9395843148231506},
#  {'label': 'Negative', 'score': 0.9896385669708252},
#  {'label': 'Positive', 'score': 0.9974169731140137},
#  {'label': 'Positive', 'score': 0.9974254965782166},
#  {'label': 'Positive', 'score': 0.9373537302017212},
#  {'label': 'Negative', 'score': 0.9818114638328552},
#  {'label': 'Positive', 'score': 0.9990372657775879},
#  {'label': 'Positive', 'score': 0.9222536683082581},
#  {'label': 'Negative', 'score': 0.575126051902771},
#  {'label': 'Positive', 'score': 0.9968421459197998},
#  {'label': 'Negative', 'score': 0.9995371103286743},
#  {'label': 'Negative', 'score': 0.9993348717689514},
#  {'label': 'Positive', 'score': 0.9932461977005005},
#  {'label': 'Positive', 'score': 0.9811111092567444},
#  {'label': 'Negative', 'score': 0.9984573125839233},
#  {'label': 'Positive', 'score': 0.5722417235374451},
#  {'label': 'Negative', 'score': 0.9996532201766968},
#  {'label': 'Positive', 'score': 0.9985536932945251},
#  {'label': 'Positive', 'score': 0.9979557991027832},
#  {'label': 'Negative', 'score': 0.8883877992630005},
#  {'label': 'Positive', 'score': 0.995721697807312},
#  {'label': 'Negative', 'score': 0.9994382262229919},
#  {'label': 'Negative', 'score': 0.9988449811935425},
#  {'label': 'Positive', 'score': 0.9243064522743225},
#  {'label': 'Negative', 'score': 0.999714195728302},
#  {'label': 'Positive', 'score': 0.9992926120758057},
#  {'label': 'Positive', 'score': 0.9996212720870972},
#  {'label': 'Negative', 'score': 0.9979150891304016},
#  {'label': 'Negative', 'score': 0.7477682828903198},
#  {'label': 'Positive', 'score': 0.9990794658660889},
#  {'label': 'Positive', 'score': 0.9995777010917664},
#  {'label': 'Positive', 'score': 0.9996460676193237},
#  {'label': 'Positive', 'score': 0.999643087387085},
#  {'label': 'Negative', 'score': 0.9763956069946289},
#  {'label': 'Positive', 'score': 0.9810974597930908},
#  {'label': 'Positive', 'score': 0.9994646906852722},
#  {'label': 'Negative', 'score': 0.9887757301330566},
#  {'label': 'Positive', 'score': 0.9977173805236816},
#  {'label': 'Negative', 'score': 0.998082160949707},
#  {'label': 'Positive', 'score': 0.8466134071350098},
#  {'label': 'Positive', 'score': 0.9709178805351257},
#  {'label': 'Negative', 'score': 0.9954372048377991},
#  {'label': 'Positive', 'score': 0.9996098875999451},
#  {'label': 'Positive', 'score': 0.9887449145317078},
#  {'label': 'Positive', 'score': 0.9984595775604248},
#  {'label': 'Positive', 'score': 0.9994211196899414},
#  {'label': 'Positive', 'score': 0.9992438554763794},
#  {'label': 'Positive', 'score': 0.9996713399887085},
#  {'label': 'Negative', 'score': 0.9929063320159912},
#  {'label': 'Positive', 'score': 0.52842777967453},
#  {'label': 'Positive', 'score': 0.9779924750328064},
#  {'label': 'Positive', 'score': 0.5486787557601929},
#  {'label': 'Negative', 'score': 0.9976237416267395},
#  {'label': 'Positive', 'score': 0.9964323043823242},
#  {'label': 'Positive', 'score': 0.9990167617797852},
#  {'label': 'Negative', 'score': 0.804909884929657},
#  {'label': 'Negative', 'score': 0.9993046522140503},
#  {'label': 'Positive', 'score': 0.9991028308868408},
#  {'label': 'Positive', 'score': 0.8534843921661377},
#  {'label': 'Positive', 'score': 0.8334548473358154},
#  {'label': 'Positive', 'score': 0.9358702898025513},
#  {'label': 'Negative', 'score': 0.9969442486763},
#  {'label': 'Positive', 'score': 0.95890212059021},
#  {'label': 'Negative', 'score': 0.9969725608825684},
#  {'label': 'Positive', 'score': 0.9988682270050049},
#  {'label': 'Positive', 'score': 0.9985319375991821},
#  {'label': 'Positive', 'score': 0.9909980297088623},
#  {'label': 'Negative', 'score': 0.9996418952941895},
#  {'label': 'Positive', 'score': 0.9710536599159241},
#  {'label': 'Positive', 'score': 0.9993995428085327},
#  {'label': 'Positive', 'score': 0.9099196195602417},
#  {'label': 'Positive', 'score': 0.997529923915863},
#  {'label': 'Positive', 'score': 0.9992781281471252},
#  {'label': 'Negative', 'score': 0.999600350856781},
#  {'label': 'Positive', 'score': 0.9995381832122803},
#  {'label': 'Positive', 'score': 0.9931614398956299},
#  {'label': 'Positive', 'score': 0.9989150762557983},
#  {'label': 'Positive', 'score': 0.9971538782119751},
#  {'label': 'Positive', 'score': 0.9926384687423706},
#  {'label': 'Positive', 'score': 0.9987918734550476},
#  {'label': 'Negative', 'score': 0.9995768666267395},
#  {'label': 'Positive', 'score': 0.7190600037574768},
#  {'label': 'Positive', 'score': 0.9601262807846069},
#  {'label': 'Positive', 'score': 0.9947695136070251},
#  ...]

# %%
dutch_tweets = dutch_tweets.reset_index(drop=True)

# %%
dutch_tweets[['label', 'score']] = pd.DataFrame(sentiment)

# %%
dutch_tweets.to_csv('dutch_tweets_pol.csv')

# %%
# model_name = "DTAI-KULeuven/robbert-v2-dutch-sentiment"
# model = RobertaForSequenceClassification.from_pretrained(model_name)
# tokenizer = RobertaTokenizer.from_pretrained(model_name)

# classifier = pipeline('sentiment-analysis', model=model, tokenizer = tokenizer, device=0)

# Load the sentiment analysis pipeline
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
# model2 = 
sentiment_pipeline = pipeline("sentiment-analysis", model=model_name, device=0)

# Example tweet
# tweet = "UNWRA:Minstens 30 medewerkers zouden volgens Israël betrokken zijn bij terroristische aanval op 7/10/23.185 Zouden linken met gewapende tak Hamas hebben, 51 met Islamitische Jihad.Wanneer handelt @carogennez ?https://t.co/AsycYv2pyW"

# Analyze sentiment
result_all = sentiment_pipeline(tweets[tweets['lang'] == 'nl']['full_text'].to_list())
# print(result)
# Out:
# WARNING:tensorflow:From c:\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Python310\lib\site-packages\transformers\models\bert\modeling_bert.py:435: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(

# %%
dutch_tweets_all = tweets[tweets['lang'] == 'nl'].reset_index(drop=True)

# %%
dutch_tweets_all[['label', 'score']] = pd.DataFrame(result_all)

# %%
dutch_tweets_all
# Out:
#                        created_at  favorite_count  \
# 0       2024-02-18T17:37:46+00:00              93
# 1       2024-02-18T12:13:18+00:00             445
# 2       2024-02-17T06:29:11+00:00             251
# 3       2024-02-16T12:33:31+00:00              31
# 4       2024-02-14T06:45:41+00:00               0
# ...                           ...             ...
# 169232  2024-05-02T13:46:24+00:00               0
# 169233  2024-05-02T11:06:30+00:00               0
# 169234  2024-05-02T08:56:55+00:00             782
# 169235  2024-05-02T10:55:57+00:00               0
# 169236  2024-05-01T14:35:11+00:00               0
#
#                                                 full_text  \
# 0       Schokkende beelden: “UNRWA-medewerker neemt li...
# 1       Vierdaagse werkweek van 32 uur, jongeren meer ...
# 2       UNWRA:Minstens 30 medewerkers zouden volgens I...
# 3       1048 Jongeren tussen 18 en 24 jaar werden er i...
# 4       RT @MichaelFreilich: Dringend strenger optrede...
# ...                                                   ...
# 169232  RT @vlbelang: "Dit zijn de typische linkse rec...
# 169233  RT @PBoonefaes: "On sociaal te zijn hebben we ...
# 169234  Hij kwam "demonstreren" voor Hamas. Moeder pik...
# 169235  RT @PALNWS: "Als vroeger onze competitiviteit ...
# 169236  RT @V_N1WS: "Als Kabouter Lui een lidkaart zou...
#
#         has_birdwatch_notes                ident lang  quote_count  \
# 0                     False  1759271000850501861   nl            3
# 1                     False  1759189343275466980   nl            8
# 2                     False  1758740358400274623   nl            8
# 3                     False  1758469657986564350   nl            2
# 4                     False  1757657344710787269   nl            0
# ...                     ...                  ...  ...          ...
# 169232                False  1786029474951115134   nl            0
# 169233                False  1785989235729695007   nl            0
# 169234                 True  1785956623896228210   nl           37
# 169235                False  1785986579661476153   nl            0
# 169236                False  1785679364308267113   nl            0
#
#         reply_count  retweet_count  views_count birdwatch_classification  \
# 0                19             30       8025.0                      NaN
# 1               109             80      34771.0                      NaN
# 2                63             88      14767.0                      NaN
# 3                10              5       1541.0                      NaN
# 4                 0            163          NaN                      NaN
# ...             ...            ...          ...                      ...
# 169232            0              3          NaN                      NaN
# 169233            0              2          NaN                      NaN
# 169234          206            130      79662.0                      NaN
# 169235            0              1          NaN                      NaN
# 169236            0             11          NaN                      NaN
#
#        birdwatch_tags ranked_classification    label     score
# 0                 NaN                   NaN   1 star  0.400208
# 1                 NaN                   NaN  5 stars  0.428922
# 2                 NaN                   NaN   1 star  0.656130
# 3                 NaN                   NaN   1 star  0.491863
# 4                 NaN                   NaN   1 star  0.703010
# ...               ...                   ...      ...       ...
# 169232            NaN                   NaN   1 star  0.543140
# 169233            NaN                   NaN   1 star  0.674253
# 169234            NaN                   NaN   1 star  0.413162
# 169235            NaN                   NaN   1 star  0.279635
# 169236            NaN                   NaN   1 star  0.471304
#
# [169237 rows x 15 columns]

# %%
dutch_tweets_all.to_csv('dutch_tweets_all.csv')

# %%
pd.read_csv('dutch_tweets_all.csv')
# Out:
# C:\Users\azkad\AppData\Local\Temp\ipykernel_13180\3350222293.py:1: DtypeWarning: Columns (11,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('dutch_tweets_all.csv')
#         Unnamed: 0                 created_at  favorite_count  \
# 0                0  2024-02-18T17:37:46+00:00              93
# 1                1  2024-02-18T12:13:18+00:00             445
# 2                5  2024-02-17T06:29:11+00:00             251
# 3                6  2024-02-16T12:33:31+00:00              31
# 4                7  2024-02-14T06:45:41+00:00               0
# ...            ...                        ...             ...
# 169232      340704  2024-05-02T13:46:24+00:00               0
# 169233      340705  2024-05-02T11:06:30+00:00               0
# 169234      340707  2024-05-02T08:56:55+00:00             782
# 169235      340708  2024-05-02T10:55:57+00:00               0
# 169236      340709  2024-05-01T14:35:11+00:00               0
#
#                                                 full_text  \
# 0       Schokkende beelden: “UNRWA-medewerker neemt li...
# 1       Vierdaagse werkweek van 32 uur, jongeren meer ...
# 2       UNWRA:Minstens 30 medewerkers zouden volgens I...
# 3       1048 Jongeren tussen 18 en 24 jaar werden er i...
# 4       RT @MichaelFreilich: Dringend strenger optrede...
# ...                                                   ...
# 169232  RT @vlbelang: "Dit zijn de typische linkse rec...
# 169233  RT @PBoonefaes: "On sociaal te zijn hebben we ...
# 169234  Hij kwam "demonstreren" voor Hamas. Moeder pik...
# 169235  RT @PALNWS: "Als vroeger onze competitiviteit ...
# 169236  RT @V_N1WS: "Als Kabouter Lui een lidkaart zou...
#
#         has_birdwatch_notes                ident lang  quote_count  \
# 0                     False  1759271000850501861   nl            3
# 1                     False  1759189343275466980   nl            8
# 2                     False  1758740358400274623   nl            8
# 3                     False  1758469657986564350   nl            2
# 4                     False  1757657344710787269   nl            0
# ...                     ...                  ...  ...          ...
# 169232                False  1786029474951115134   nl            0
# 169233                False  1785989235729695007   nl            0
# 169234                 True  1785956623896228210   nl           37
# 169235                False  1785986579661476153   nl            0
# 169236                False  1785679364308267113   nl            0
#
#         reply_count  retweet_count  views_count birdwatch_classification  \
# 0                19             30       8025.0                      NaN
# 1               109             80      34771.0                      NaN
# 2                63             88      14767.0                      NaN
# 3                10              5       1541.0                      NaN
# 4                 0            163          NaN                      NaN
# ...             ...            ...          ...                      ...
# 169232            0              3          NaN                      NaN
# 169233            0              2          NaN                      NaN
# 169234          206            130      79662.0                      NaN
# 169235            0              1          NaN                      NaN
# 169236            0             11          NaN                      NaN
#
#        birdwatch_tags ranked_classification    label     score
# 0                 NaN                   NaN   1 star  0.400208
# 1                 NaN                   NaN  5 stars  0.428922
# 2                 NaN                   NaN   1 star  0.302064
# 3                 NaN                   NaN   1 star  0.549122
# 4                 NaN                   NaN   1 star  0.601674
# ...               ...                   ...      ...       ...
# 169232            NaN                   NaN      NaN       NaN
# 169233            NaN                   NaN      NaN       NaN
# 169234            NaN                   NaN      NaN       NaN
# 169235            NaN                   NaN      NaN       NaN
# 169236            NaN                   NaN      NaN       NaN
#
# [169237 rows x 16 columns]
