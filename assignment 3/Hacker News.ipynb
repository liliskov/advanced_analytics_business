# %% [markdown]
# # Assignment 3: Construction of a predictive model using Spark Structured Streaming and textual data (Hacker News)

# %% [markdown]
# ## 1. Construction of a data set using the provided stream

# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):
        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-JK21LNQ3:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
socketDF = spark.readStream.format("socket").option("host", "seppe.net").option("port", 7778).load()
socketDF.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
from pyspark.sql.functions import from_json, schema_of_json

# %%
def process_row(df, epoch_id):
    print(epoch_id)
    if df.count() == 0: return
    schema = schema_of_json(df.first().value)
    df_cols = df.selectExpr('CAST(value AS STRING)')\
        .select(from_json('value', schema)\
        .alias('temp'))\
        .select('temp.*')
    df_cols.show()
    # We can also save here using something such as:
    df.write.format("json").mode("append").save("data")

# %%
query = socketDF.writeStream.trigger(processingTime='5 seconds').foreachBatch(process_row).start()
# Out:
# 0
# 1
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|          user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |40191264|       0| theatlantic.com|    false|2024-04-28 19:47:46|The New Quarter-L...|The New Quarter-L...|The New Quarter-L...|https://www.theat...|    wallflower|    1|
# |40191287|       0|tamanotchi.world|    false|2024-04-28 19:52:10|tamanotchi.world ...|tamanotchi.world ...|TamaNOTchi – Cute...|https://tamanotch...|      memalign|    1|
# |40191312|       2|     autodocs.me|    false|2024-04-28 19:55:53|AutoDocs\n\nAutoD...|            AutoDocs|Show HN: Auto-upd...|https://www.autod...|ayushrodrigues|    2|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
#
# 2
# +--------+--------+------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |     aid|comments|            domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|        user|votes|
# +--------+--------+------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |40191313|       0|      hackaday.com|    false|2024-04-28 19:55:57|Chinese Subs May ...|Chinese Subs May ...|Chinese Subs May ...|https://hackaday....|stareatgoats|    1|
# |40191325|       0|garrisonjensen.com|    false|2024-04-28 19:57:20|Garrison Jensen -...|Garrison Jensen -...|Sorted Containers...|https://www.garri...|   garrisonj|    1|
# +--------+--------+------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
#
# 3
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|       user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |40191346|      10|houstonchronicle.com|     true|2024-04-28 19:59:57|Access to this pa...|Access to this pa...|'Catastrophic gri...|https://www.houst...|MilnerRoute|   23|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
#
# 4
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|      user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |40191353|     139|curingaddiction.s...|     true|2024-04-28 20:00:48|"Growing concerns...|"Growing concerns...|Ozempic will disr...|https://curingadd...|robertn702|  115|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
#
# 5
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40191419|       0|nbcnews.com|    false|2024-04-28 20:14:54|How Liquid Death ...|It’s just water i...|Liquid Death beca...|https://www.nbcne...|networked|    2|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 6
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------+--------------------+--------------------+-------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|  source_title|               title|                 url|   user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------+--------------------+--------------------+-------+-----+
# |40191430|       0|textswithfounders...|    false|2024-04-28 20:16:16|NPS Calculator\n\...|NPS Calculator|Was unimpressed b...|https://nps.texts...|weisser|    1|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------+--------------------+--------------------+-------+-----+
#
# 7
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|    user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |40191445|       0|austinhenley.com|    false|2024-04-28 20:17:49|Mistakes that dat...|Mistakes that dat...|Mistakes that dat...|https://austinhen...|azhenley|    1|
# |40191446|       0| ingebrigtsen.no|    false|2024-04-28 20:18:13|The Simplest Thin...|The Simplest Thin...|The Simplest Thin...|https://lars.inge...|    deng|    1|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
#
# 8
# +--------+--------+-----------+---------+-------------------+--------------------+------------+------------+--------------------+--------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|source_title|       title|                 url|    user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+------------+------------+--------------------+--------+-----+
# |40191447|       0|youtube.com|    false|2024-04-28 20:18:25|PIP Boy 3000 - Yo...|PIP Boy 3000|Pip Boy 3000|https://www.youtu...|brudgers|    1|
# +--------+--------+-----------+---------+-------------------+--------------------+------------+------------+--------------------+--------+-----+
#
# 9
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|       user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |40191461|       0|nytimes.com|    false|2024-04-28 20:20:12|Opinion | Simple ...|Opinion | Art Isn...|Art isn't suppose...|https://www.nytim...|GeoAtreides|    1|
# |40191480|       0|pdflabs.com|    false|2024-04-28 20:21:59|PDFtk - The PDF T...|PDFtk - The PDF T...|PDFtk is a simple...|https://www.pdfla...|       gjvc|    2|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# 10
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|           domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40191483|       0|hakaimagazine.com|    false|2024-04-28 20:22:24|The Waning Reign ...|The Waning Reign ...|The Waning Reign ...|https://hakaimaga...|PaulHoule|    1|
# |40191486|       0|  alexanderell.is|    false|2024-04-28 20:22:35|Harry Chapin and ...|Harry Chapin and ...|Harry Chapin and ...|https://alexander...|    otras|    1|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 11
# +--------+--------+--------------------+---------+-------------------+--------------------+----------------+--------------------+--------------------+-----+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|    source_title|               title|                 url| user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+----------------+--------------------+--------------------+-----+-----+
# |40191494|       0|saigaddam.medium.com|    false|2024-04-28 20:23:28|Just a moment...\...|Just a moment...|Consciousness is ...|https://saigaddam...|baxtr|    1|
# +--------+--------+--------------------+---------+-------------------+--------------------+----------------+--------------------+--------------------+-----+-----+
#
# 12
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|           domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40191510|       0|github.com/gyf304|     true|2024-04-28 20:25:46|GitHub - gyf304/d...|GitHub - gyf304/d...|Show HN: Dotenv, ...|https://github.co...|gyf304|    8|
# |40191560|       0|      youtube.com|    false|2024-04-28 20:32:17|100% Local "AI To...|100% Local "AI To...|100% Local "AI To...|https://www.youtu...| amrrs|    1|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 13
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |     aid|comments|       domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|      user|votes|
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |40191603|       0|sitepoint.com|    false|2024-04-28 20:37:23|Creating Fluid Ty...|Creating Fluid Ty...|Creating Fluid Ty...|https://www.sitep...|dainemawer|    1|
# |40191607|       0|  youtube.com|    false|2024-04-28 20:37:40|Rabbit R1 - We Go...|Rabbit R1 - We Go...|Rabbit R1 Discuss...|https://www.youtu...|    jasong|    1|
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
#
# 14
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|       domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40191612|       0|criterion.com|    false|2024-04-28 20:38:14|Attention Require...|Attention Require...|Welt Am Draht (Wo...|https://www.crite...|bpiche|    2|
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 15
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|   user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
# |40191619|       0|tomshardware.com|    false|2024-04-28 20:39:06|Drone maker DJI f...|Drone maker DJI f...|Drone maker DJI f...|https://www.tomsh...|elorant|    2|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
#
# 16
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|          user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |40191636|       0|cheapskatesguide.org|    false|2024-04-28 20:40:41|cheapskatesguide....|cheapskatesguide.org|A Free PHP Webpag...|https://cheapskat...|worldofmatthew|    2|
# |40191637|       0|          oracle.com|    false|2024-04-28 20:40:44|blogs.oracle.com\...|    blogs.oracle.com|The Ksplice Point...|https://blogs.ora...|      rrampage|    1|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
#
# 17
# +--------+--------+-------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |     aid|comments|             domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|          user|votes|
# +--------+--------+-------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |40191686|       0|        youtube.com|    false|2024-04-28 20:45:14|Managing your ADH...|Managing your ADH...|           ADHD Work|https://www.youtu...|hidelooktropic|    2|
# |40191693|       0|github.com/keidarcy|    false|2024-04-28 20:45:48|GitHub - keidarcy...|GitHub - keidarcy...|   E1S – K9s for ECS|https://github.co...|        tildef|    1|
# |40191701|       0|    theatlantic.com|    false|2024-04-28 20:46:29|The Happiness Tri...|The Happiness Tri...|The Happiness Tri...|https://www.theat...|    throw0101c|    1|
# +--------+--------+-------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
#
# 18
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |     aid|comments|           domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|        user|votes|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |40191715|       0|      fortune.com|    false|2024-04-28 20:48:14|Global debt hasn'...|Global debt hasn'...|Global debt hasn'...|https://fortune.c...|    thomasfl|    1|
# |40191723|       4|github.com/ollama|     true|2024-04-28 20:48:42|Release v0.1.33 ·...|Release v0.1.33 ·...|Ollama v0.1.33 wi...|https://github.co...|ashvardanian|   15|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# 19
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|           user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----+
# |40191728|       0|alaniswright.com|    false|2024-04-28 20:49:57|8 ways I am using...|8 ways I am using...|8 ways I am using...|https://alaniswri...|PuddleOfSausage|    1|
# |40191731|       0|    esolangs.org|    false|2024-04-28 20:49:59|BytePusher - Esol...|BytePusher - Esolang|          BytePusher|https://esolangs....|           hggh|    1|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----+
#
# 20
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|       user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |40191735|       0|github.com/asadm|    false|2024-04-28 20:50:17|GitHub - asadm/ma...|GitHub - asadm/ma...|Show HN: I made a...|https://github.co...|    asadalt|    2|
# |40191783|       0|        cnbc.com|    false|2024-04-28 20:54:57|Digital ad market...|Digital ad market...|Digital ad market...|https://www.cnbc....|EhsanEtezad|    1|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
#
# 21
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40191816|       0|theverge.com|    false|2024-04-28 20:58:26|The Apple Vision ...|The Apple Vision ...|The Apple Vision ...|https://www.theve...|latexr|    1|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 22
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|           user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----+
# |40191825|       0|      nextdns.io|    false|2024-04-28 20:59:49|NextDNS - The new...|             NextDNS|             NextDNS| https://nextdns.io/|amirmasoudabdol|    1|
# |40191856|       0|atlasobscura.com|    false|2024-04-28 21:02:12|Ra Paulette's Han...|Ra Paulette's Han...|Ra Paulette's Han...|https://www.atlas...|         Anon84|    1|
# |40191862|       0|   microsoft.com|    false|2024-04-28 21:02:30|Fun with names | ...|      Fun with names|Larry Osterman on...|https://learn.mic...|      aragonite|    1|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------------+-----+
#
# 23
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40191861|       0|theguardian.com|    false|2024-04-28 21:02:30|‘Miss AI’ is bill...|‘Miss AI’ is bill...|'Miss AI' feels l...|https://www.thegu...| smartmic|    1|
# |40191884|       0|    tbhaxor.com|    false|2024-04-28 21:04:13|Why Pivot Root is...|Why Pivot Root is...|Why pivot root is...|https://tbhaxor.c...|ahmetozer|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 24
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+----+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|source_title|               title|                 url|user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+----+-----+
# |40191890|       0|twitter.com/cockt...|    false|2024-04-28 21:04:58|X\n\nDon’t miss w...|           X|AI Town fork with...|https://twitter.c...|tosh|    2|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+----+-----+
#
# 25
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|      user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40192440|       0|livescience.com|    false|2024-04-28 22:10:44|Can humans see ul...|Can humans see ul...|Can humans see ul...|https://www.lives...|bookofjoe|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 44
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|          user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |40192442|       0|          bun.sh|    false|2024-04-28 22:11:03|Bun v1.1.6 | Bun ...|Bun v1.1.6 | Bun ...|          Bun v1.1.6|https://bun.sh/bl...|herpderperator|    3|
# |40192502|       0|     hexroll.app|    false|2024-04-28 22:21:30|HEXROLL - roll yo...|      Roll a sandbox|Create an entire ...|https://hexroll.app/|   Marine4Life|    1|
# |40192524|       0|eclecticlight.co|    false|2024-04-28 22:24:15|Last Week on My M...|Last Week on My Mac:|  Fun and Functional|https://eclecticl...|       frizlab|    1|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
#
# 45
# +--------+--------+-------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|             domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|       user|votes|
# +--------+--------+-------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |40192552|       0|github.com/carsonpo|    false|2024-04-28 22:27:34|GitHub - carsonpo...|GitHub - carsonpo...|Haystack DB – 10x...|https://github.co...|carsonpoole|    1|
# +--------+--------+-------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# 46
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|       user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |40192566|       0|        cnn.com|    false|2024-04-28 22:29:33|edition.cnn.com\n...|     edition.cnn.com|Sexsomnia: An emb...|https://www.cnn.c...|Stratoscope|    1|
# |40192579|       0|        acm.org|     true|2024-04-28 22:30:55|                \n\n|                NULL|The Essence of Co...|https://dl.acm.or...| swatson741|    4|
# |40192594|       0|github.com/sass|    false|2024-04-28 22:32:42|Violation of the ...|Violation of the ...|The Sass project ...|https://github.co...|   zaerthyn|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
#
# 47
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |40192618|       0| youtube.com|     true|2024-04-28 22:37:41|       \n\n|        NULL|Oxford Mathematic...|https://www.youtu...|   gjvc|    6|
# |40192648|       0|ofbizian.com|    false|2024-04-28 22:41:59|       \n\n|        NULL|Product-Market Fi...|http://www.ofbizi...|bibryam|    2|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
#
# 48
# +--------+--------+------+---------+-------------------+-----------+------------+--------------------+--------------------+----+-----+
# |     aid|comments|domain|frontpage|          posted_at|source_text|source_title|               title|                 url|user|votes|
# +--------+--------+------+---------+-------------------+-----------+------------+--------------------+--------------------+----+-----+
# |40192649|       0|qz.com|    false|2024-04-28 22:42:01|       \n\n|        NULL|Apophis will swin...|https://qz.com/ho...|geox|    2|
# +--------+--------+------+---------+-------------------+-----------+------------+--------------------+--------------------+----+-----+
#
# 49
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+----------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|source_text|source_title|               title|                 url|      user|votes|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+----------+-----+
# |40192664|       0|github.com/rayking99|    false|2024-04-28 22:43:26|       \n\n|        NULL|Block* and AgentF...|https://github.co...|jasepickup|    2|
# |40192669|       0|            wanix.sh|    false|2024-04-28 22:44:07|       \n\n|        NULL|Web-native Unix-l...|   https://wanix.sh/|   aziis98|    3|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+----------+-----+
#
# 50
# +--------+--------+-----------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments|           domain|frontpage|          posted_at|source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+-----------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |40192698|       0|reactivemicro.com|     true|2024-04-28 22:49:17|       \n\n|        NULL|6502 – Guideline ...|https://downloads...|siraben|    4|
# +--------+--------+-----------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
#
# 51
# +--------+--------+-------------+---------+-------------------+-----------+------------+--------------------+--------------------+----------+-----+
# |     aid|comments|       domain|frontpage|          posted_at|source_text|source_title|               title|                 url|      user|votes|
# ...
# +--------+--------+-------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |40192764|       0|       gov.sa|    false|2024-04-28 22:59:39|       \n\n|        NULL|Saudi Data and Al...|https://sdaia.gov...|  mooreds|    2|
# |40192772|       0|wikipedia.org|    false|2024-04-28 23:00:45|       \n\n|        NULL|          Phosphenes|https://en.wikipe...|radeeyate|    1|
# +--------+--------+-------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
#
# 54
# +--------+--------+-------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
# |     aid|comments| domain|frontpage|          posted_at|source_text|source_title|               title|                 url|  user|votes|
# +--------+--------+-------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
# |40192775|       0|acm.org|    false|2024-04-28 23:01:13|       \n\n|        NULL|Polynima: Practic...|https://dl.acm.or...|matt_d|    1|
# +--------+--------+-------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
#
# 55
# +--------+--------+------------------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
# |     aid|comments|            domain|frontpage|          posted_at|source_text|source_title|               title|                 url|  user|votes|
# +--------+--------+------------------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
# |40192783|       0|washingtonpost.com|    false|2024-04-28 23:02:41|       \n\n|        NULL|Finding space for...|https://www.washi...|rustoo|    1|
# +--------+--------+------------------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
# 56
# +--------+--------+-------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments| domain|frontpage|          posted_at|source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+-------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |40192813|       0|cdr.fyi|    false|2024-04-28 23:07:34|       NULL|        NULL|A New API for Car...|https://www.cdr.f...|cdr_fyi|    1|
# +--------+--------+-------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
#
# 57
# +--------+--------+---------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|source_text|source_title|               title|                 url|     user|votes|
# +--------+--------+---------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |40192815|       0|gist.github.com|    false|2024-04-28 23:07:47|       NULL|        NULL|Using Jemalloc 5 ...|https://gist.gith...|  mooreds|    3|
# |40192817|       0|     reason.com|    false|2024-04-28 23:08:52|       NULL|        NULL|In the AI Economy...|https://reason.co...|Bostonian|    5|
# +--------+--------+---------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
#
# 58
# +--------+--------+----------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments|    domain|frontpage|          posted_at|source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+----------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |40192819|       0|kanidm.com|    false|2024-04-28 23:09:08|       NULL|        NULL|Kanidm is a moder...| https://kanidm.com/|mooreds|    1|
# |40192847|       0|   welt.de|    false|2024-04-28 23:14:18|       NULL|        NULL|Islamists demonst...|https://www.welt....| lisper|    1|
# +--------+--------+----------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
#
# 59
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |40192858|       0|lynalden.com|    false|2024-04-28 23:15:51|       NULL|        NULL|Most Investments ...|https://www.lynal...|bilsbie|    1|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
#
# 60
# +--------+--------+----------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|source_text|source_title|               title|                 url|          user|votes|
# +--------+--------+----------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------------+-----+
# |40192880|       2|seattletimes.com|    false|2024-04-28 23:17:51|       NULL|        NULL|Jassy, Bezos, oth...|https://www.seatt...|    deviantbit|    3|
# |40192921|       0| dailymail.co.uk|    false|2024-04-28 23:25:17|       NULL|        NULL|Pete Ballmer: wha...|https://www.daily...|  andrewstuart|    2|
# |40192922|       0|     mudman.blog|    false|2024-04-28 23:25:38|       NULL|        NULL|What Is the Cost ...|https://mudman.bl...|pureheartlover|    2|
# +--------+--------+----------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------------+-----+
#
# 61
# +--------+--------+-----------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|source_text|source_title|               title|                 url|  user|votes|
# +--------+--------+-----------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
# |40192927|       0|youtube.com|    false|2024-04-28 23:26:56|       \n\n|        NULL|The king of game ...|https://www.youtu...|nickca|    1|
# +--------+--------+-----------+---------+-------------------+-----------+------------+--------------------+--------------------+------+-----+
#
# 62
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
# |40192932|       0|didyouknowbg8.wor...|    false|2024-04-28 23:27:54|       \n\n|        NULL|Cognita: Retrieve...|https://didyoukno...|allpaca|    1|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+-------+-----+
#
# 63
# +--------+--------+---------------+---------+-------------------+-----------+------------+-------------+--------------------+-------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|source_text|source_title|        title|                 url|   user|votes|
# +--------+--------+---------------+---------+-------------------+-----------+------------+-------------+--------------------+-------+-----+
# |40192950|       0|gist.github.com|    false|2024-04-28 23:31:09|       \n\n|        NULL|Space Matters|https://gist.gith...|chadsix|    1|
# +--------+--------+---------------+---------+-------------------+-----------+------------+-------------+--------------------+-------+-----+
#
# 64
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|source_text|source_title|               title|                 url|       user|votes|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+-----------+-----+
# |40192960|       0|medium.com/tonist...|    false|2024-04-28 23:32:08|       \n\n|        NULL|New Dockerfile Ca...|https://medium.co...|alexzeitler|    2|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+-----------+-----+
#
# 65
# +--------+--------+---------------+---------+-------------------+-----------+------------+--------------------+--------------------+----------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|source_text|source_title|               title|                 url|      user|votes|
# +--------+--------+---------------+---------+-------------------+-----------+------------+--------------------+--------------------+----------+-----+
# |40192972|       0|github.com/tmux|    false|2024-04-28 23:34:12|       \n\n|        NULL|Chained ttys for ...|https://github.co...|reportaman|    1|
# +--------+--------+---------------+---------+-------------------+-----------+------------+--------------------+--------------------+----------+-----+
#
# 66
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|source_text|source_title|               title|                 url|       user|votes|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-----------+-----+
# |40192992|       0|catonmat.net|    false|2024-04-28 23:37:49|       \n\n|        NULL|A proof that Unix...|https://catonmat....|  sebmellen|    2|
# |40193023|       0| youtube.com|    false|2024-04-28 23:45:39|       NULL|        NULL|Jeffrey Ventrella...|https://www.youtu...|LichenStone|    2|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+-----------+-----+
# 67
# +--------+--------+----------+---------+-------------------+-----------+------------+--------------------+--------------------+--------+-----+
# |     aid|comments|    domain|frontpage|          posted_at|source_text|source_title|               title|                 url|    user|votes|
# +--------+--------+----------+---------+-------------------+-----------+------------+--------------------+--------------------+--------+-----+
# |40193037|       0|deramp.com|    false|2024-04-28 23:47:44|       NULL|        NULL|Recollections of ...|https://deramp.co...|mmastrac|    1|
# +--------+--------+----------+---------+-------------------+-----------+------------+--------------------+--------------------+--------+-----+
#
# 68
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|source_text|source_title|               title|                 url|    user|votes|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------+-----+
# |40193071|       0|aistickergenerato...|    false|2024-04-28 23:54:40|       NULL|        NULL|AI Sticker Genera...|https://aisticker...|starboat|    1|
# +--------+--------+--------------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------+-----+
#
# 69
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|source_text|source_title|               title|                 url|     user|votes|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |40193089|       0| github.blog|    false|2024-04-28 23:58:41|       NULL|        NULL|GitHub Actions, A...|https://github.bl...|   Alupis|    1|
# |40193095|       2|buildbook.us|    false|2024-04-28 23:59:47|       NULL|        NULL|Show HN: YC Co-Fo...|http://buildbook....|McLarenF1|    1|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
#
# 70
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|source_text|source_title|               title|                 url|          user|votes|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------------+-----+
# |40193106|       0|     cnn.com|    false|2024-04-29 00:02:26|       NULL|        NULL|FDIC says Republi...|https://www.cnn.c...|       mooreds|    3|
# |40193112|       0|futurism.com|    false|2024-04-29 00:05:02|       NULL|        NULL|Catholic Group Qu...|https://futurism....|        madpen|    1|
# |40193117|       0|     wsj.com|    false|2024-04-29 00:05:51|       NULL|        NULL|Why China Keeps M...|https://www.wsj.c...|JumpCrisscross|    1|
# +--------+--------+------------+---------+-------------------+-----------+------------+--------------------+--------------------+--------------+-----+
#
# 71
# +--------+--------+---------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |     aid|comments|   domain|frontpage|          posted_at|source_text|source_title|               title|                 url|     user|votes|
# +--------+--------+---------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |40193148|       0|wired.com|    false|2024-04-29 00:13:29|       NULL|        NULL|National Security...|https://www.wired...|bookofjoe|    1|
# |40193155|       0|  twz.com|    false|2024-04-29 00:14:11|       NULL|        NULL|Ukraine Appears t...|https://www.twz.c...| peutetre|    1|
# +--------+--------+---------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
#
# 72
# +--------+--------+----------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|source_text|source_title|               title|                 url|     user|votes|
# +--------+--------+----------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+
# |40193159|       0|cryptocellar.org|    false|2024-04-29 00:14:54|       NULL|        NULL|The History of No...|https://cryptocel...|aragonite|    1|
# +--------+--------+----------------+---------+-------------------+-----------+------------+--------------------+--------------------+---------+-----+

# %%
query.stop()

# %% [markdown]
# The historical data that was collected through the provided stream represents JSON dictionaries containing the following 11 variables:
# - id
# - title
# - url
# - domain (i.e., the website where a given article is published)
# - votes
# - user
# - posted_at (in the format "yyyy-mm-dd hh:mm:ss)
# - comments
# - source_title
# - source_text
# - frontpage (i.e. our target)

# %% [markdown]
# ## 2. Building the model to predict the target ("frontpage") based on the available features

# %% [markdown]
# Things to be taken into account:
# 1) Data imbalance in Y ("front_page"): "true" values are too few, "false" values are too many.
#
# Possible solutions: oversampling, undersampling etc.

# %%
#Building the model using spark.ml (MLlib)

# %% [markdown]
# ## 3. Using the trained model to make predictions as the stream comes in

# %% [markdown]
# I.e. show that we can connect to the data source, preprocess/featurize incoming messages, have our model predict the label, and show it, similar to spark_streaming_example_predicting.ipynb.

# %% [markdown]
# ## Conclusion
