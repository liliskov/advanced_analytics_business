# %% [markdown]
# # PREPROCESSING PIPELINE

# %%
# Standard library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sklearn models
from sklearn.ensemble import (RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier)
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB

# Sklearn preprocessing and pipeline
from sklearn.preprocessing import (OneHotEncoder, QuantileTransformer, FunctionTransformer)
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectFromModel
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Sklearn utilities
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn import set_config
set_config(transform_output='pandas')

# %%
# Load data
train_data=pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

X_train = train_data.drop('target', axis=1)
y_train = train_data['target']

# %%
# Create a function to treat the date and id variables and turn it into an sklearn transformer

def date_and_id(data):
    
    # ensure 'Connect_Date' is of the correct type and correct for Y2K
    date_df = pd.DataFrame()
    date_df['Connect_Date'] = pd.to_datetime(data['Connect_Date'], format='%d/%m/%y')
    date_df['Connect_Date'] = date_df['Connect_Date'].apply(lambda x: x - pd.DateOffset(years=100) if x.year > 2022 else x)
    
    # Create features out of the "Connect_Date" variable
    reference_date = pd.to_datetime('2023-01-01')
    date_df['Account_Age_days'] = (reference_date - date_df['Connect_Date']).dt.days
    date_df['Connect_Month'] = date_df['Connect_Date'].dt.month
    date_df['Connect_Quarter'] = date_df['Connect_Date'].dt.quarter
    date_df['Connect_Year'] = date_df['Connect_Date'].dt.year

    # Put the new features back to the dataset and remove the 'id' column
    date_df=date_df.drop('Connect_Date', axis=1)
    res = pd.concat([data.drop('Connect_Date', axis=1), date_df], axis=1)
    res = res.drop('id', axis=1)
    return res

date_id_preprocessor = FunctionTransformer(date_and_id)

# %%
# Transformer to impute missing values in certain variables

numeric_missing = ['Dropped_calls_ratio', 'call_cost_per_min']
categorical_missing = ['Usage_Band']

imputer = ColumnTransformer(transformers=[
    ('num_na', SimpleImputer(strategy='median'), numeric_missing),
    ('cat_na', SimpleImputer(strategy='most_frequent'), categorical_missing),
], remainder='passthrough', verbose_feature_names_out=False)

# %%
# Transformer to one-hot encode categorical data and quantile-transform numeric data

numeric_columns = list(train_data.drop('target', axis=1)._get_numeric_data().columns)
categorical_columns = list(set(train_data.columns) - set(numeric_columns))
categorical_columns = [i for i in categorical_columns if i not in ['Connect_Date','id', 'target']]

transformer = ColumnTransformer(transformers=[
    ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop='first'), categorical_columns),
    ('quant', QuantileTransformer(output_distribution = 'normal', random_state = 0), numeric_columns)
], remainder='passthrough', verbose_feature_names_out=False)

# %%
# Custom transformer to remove correlated features

class RemoveCorrelatedFeatures(BaseEstimator, TransformerMixin):
    def __init__(self, threshold=0.95):
        self.threshold = threshold
        self.correlated_features = None

    def fit(self, X, y=None):
        # Calculate the correlation matrix
        corr_matrix = X.corr().abs()
        # Select upper triangle of correlation matrix
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
        # Find index of feature columns with correlation greater than the threshold
        self.correlated_features = [column for column in upper.columns if any(upper[column] > self.threshold)]
        return self

    def transform(self, X):
        # Drop highly correlated features
        X = X.drop(columns=self.correlated_features, errors='ignore')
        return X

# %%
# The preprocessing-classifier pipeline

p = Pipeline(steps=[
    ('dtid', date_id_preprocessor),
    ('impu', imputer),
    ('trfm', transformer),
    ('rffs', SelectFromModel(RandomForestClassifier(random_state=0), threshold=0.01)),
    ('corr', RemoveCorrelatedFeatures(threshold=0.7)),
    ('classifier', LogisticRegression())
])

# %% [markdown]
# # MODEL FITTER

# %%
# Define custom metric (profit at top 20 prediction)

def profit_top_20(y_true, y_pred):
    dft = y_true.to_frame()
    dft['y_pred'] = y_pred
    dft = dft.sort_values('y_pred', ascending=False).head(20)
    dft = dft[dft['target'] == 1]
    profit = train_data['average cost min'][dft.index].sum()
    return profit

# %%
# GridSearchCV does exhaustive search on all model/param combination, expect it to take some time

# Object for managing multiple searches

class Search():
    
    def __init__(self):
        self.runs = dict()
    
    def run(self, run_name, param_grid, X_train, y_train, estimator=p, cv=5):

        # Use GridSearchCV to search for the best classifier and classifier parameters
        grid_search = GridSearchCV(estimator, param_grid, cv, scoring=make_scorer(profit_top_20, response_method="predict_proba", greater_is_better=True), n_jobs=-1, verbose=2)
        grid_search.fit(X_train, y_train)
        self.runs[run_name] = grid_search
        print ("see results dataframe by accessing the object's .result(run_name)")

    def result(self, run_name):
        return pd.DataFrame(self.runs[run_name].cv_results_)
    
    def predict(self, run_name, pred_data, export=False):
        res = self.runs[run_name].predict_proba(test_data)
        res = pd.concat([pred_data['id'], pd.Series([i[1] for i in res])], axis=1)
        if export is True:
            res.to_csv(run_name + '.csv', header=False, index=False)
        elif isinstance(export, str):
            res.to_csv(export + '.csv', header=False, index=False)
        return res

# %%
fitter = Search()

# %% [markdown]
# ## SAMPLE RUNS

# %%
# Define the parameter grid for all the classifiers we want to try

param_grid = [
    {'classifier': [LogisticRegression(max_iter=1000)],
     'classifier__C': [3, 10, 30, 100],
     'classifier__solver': ['liblinear', 'saga'],  # 'liblinear' and 'saga' work well with small datasets and L1 penalty
     'classifier__penalty': ['l1', 'l2']},
    
    {'classifier': [RandomForestClassifier()],
     'classifier__n_estimators': [50, 75, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [10, 20, 30]},
    
    {'classifier': [GradientBoostingClassifier()],
     'classifier__n_estimators': [50, 100, 150],
     'classifier__learning_rate': [0.1, 0.15, 0.2],
     'classifier__max_depth': [3, 5, 7]}
]

fitter.fit('first', param_grid, X_train, y_train)
# Out:
# Fitting 5 folds for each of 61 candidates, totalling 305 fits
# see results dataframe by accessing the object's .result(run_name)

# %%
fitter.result('first').sort_values('mean_test_score', ascending=False)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        2.886199      0.126983         0.116400        0.011977
# 1        3.481198      0.222346         0.128200        0.015867
# 4        3.017399      0.158965         0.135601        0.027302
# 5        4.029799      0.488782         0.121801        0.010265
# 6        3.607801      0.748012         0.136399        0.037329
# ..            ...           ...              ...             ...
# 58       6.139000      0.828675         0.116400        0.005004
# 46       5.147145      0.971601         0.115999        0.020465
# 50       9.357200      1.160856         0.122600        0.007659
# 31       3.785234      0.145016         0.135600        0.010929
# 22       4.215600      0.452301         0.139999        0.020151
#
#                      param_classifier param_classifier__C  \
# 0   LogisticRegression(max_iter=1000)                   3
# 1   LogisticRegression(max_iter=1000)                   3
# 4   LogisticRegression(max_iter=1000)                  10
# 5   LogisticRegression(max_iter=1000)                  10
# 6   LogisticRegression(max_iter=1000)                  10
# ..                                ...                 ...
# 58       GradientBoostingClassifier()                 NaN
# 46       GradientBoostingClassifier()                 NaN
# 50       GradientBoostingClassifier()                 NaN
# 31           RandomForestClassifier()                 NaN
# 22           RandomForestClassifier()                 NaN
#
#    param_classifier__penalty param_classifier__solver  \
# 0                         l1                liblinear
# 1                         l1                     saga
# 4                         l1                liblinear
# 5                         l1                     saga
# 6                         l2                liblinear
# ..                       ...                      ...
# 58                       NaN                      NaN
# 46                       NaN                      NaN
# 50                       NaN                      NaN
# 31                       NaN                      NaN
# 22                       NaN                      NaN
#
#    param_classifier__max_depth param_classifier__max_features  ...  \
# 0                          NaN                            NaN  ...
# 1                          NaN                            NaN  ...
# 4                          NaN                            NaN  ...
# 5                          NaN                            NaN  ...
# 6                          NaN                            NaN  ...
# ..                         ...                            ...  ...
# 58                           7                            NaN  ...
# 46                           5                            NaN  ...
# 50                           7                            NaN  ...
# 31                          30                           log2  ...
# 22                          20                           sqrt  ...
#
#    param_classifier__learning_rate  \
# 0                              NaN
# 1                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# ..                             ...
# 58                             0.2
# 46                            0.15
# 50                            0.15
# 31                             NaN
# 22                             NaN
#
#                                                params split0_test_score  \
# 0   {'classifier': LogisticRegression(max_iter=100...          3.563949
# 1   {'classifier': LogisticRegression(max_iter=100...          3.563949
# 4   {'classifier': LogisticRegression(max_iter=100...          3.563949
# 5   {'classifier': LogisticRegression(max_iter=100...          3.563949
# 6   {'classifier': LogisticRegression(max_iter=100...          3.563949
# ..                                                ...               ...
# 58  {'classifier': GradientBoostingClassifier(), '...          2.784254
# 46  {'classifier': GradientBoostingClassifier(), '...          2.441914
# 50  {'classifier': GradientBoostingClassifier(), '...          2.511185
# 31  {'classifier': RandomForestClassifier(), 'clas...          2.221817
# 22  {'classifier': RandomForestClassifier(), 'clas...          1.883128
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            3.445613           4.024599           5.189658
# 1            3.445613           4.024599           5.189658
# 4            3.445613           4.024599           5.189658
# 5            3.445613           4.024599           5.189658
# 6            3.445613           4.024599           5.189658
# ..                ...                ...                ...
# 58           2.950014           1.906301           3.469542
# 46           2.939267           2.235129           2.988435
# 50           2.689453           2.092552           3.306216
# 31           2.495887           2.616284           2.971683
# 22           2.747159           2.261163           2.593389
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            5.334287         4.311621        0.801019                1
# 1            5.334287         4.311621        0.801019                1
# 4            5.334287         4.311621        0.801019                1
# 5            5.334287         4.311621        0.801019                1
# 6            5.334287         4.311621        0.801019                1
# ..                ...              ...             ...              ...
# 58           2.044264         2.630875        0.582728               57
# 46           2.429802         2.606909        0.300943               58
# 50           2.398705         2.599622        0.403151               59
# 31           2.546203         2.570375        0.241156               60
# 22           2.676187         2.432205        0.321075               61
#
# [61 rows x 21 columns]

# %%
fitter.predict('first', test_data)
# Out:
#            id         0
# 0     K751808  0.013287
# 1     K837351  0.017356
# 2     K548114  0.016381
# 3     K736156  0.012953
# 4     K508080  0.036996
# ...       ...       ...
# 1677  K588314  0.015316
# 1678  K826807  0.066678
# 1679  K982731  0.045070
# 1680  K623037  0.073918
# 1681  K883413  0.036939
#
# [1682 rows x 2 columns]

# %%
# Trying Lili's method (fit on top spenders)

high_spenders_threshold = np.quantile(train_data['average cost min'], 0.92)
high_spenders_data = train_data[train_data['average cost min'] > high_spenders_threshold]
high_X_train = train_data.drop('target', axis=1)
high_y_train = train_data['target']

# Everything under the sun because why not

param_grid = [
    {'classifier': [LogisticRegression(max_iter=1000)],
     'classifier__C': [3, 10, 30, 100],
     'classifier__solver': ['liblinear', 'saga'],
     'classifier__penalty': ['l1', 'l2']},
    
    {'classifier': [RandomForestClassifier()],
     'classifier__n_estimators': [50, 75, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [10, 20, 30]},
    
    {'classifier': [GradientBoostingClassifier()],
     'classifier__n_estimators': [50, 100, 150],
     'classifier__learning_rate': [0.1, 0.15, 0.2],
     'classifier__max_depth': [3, 5, 7]},

    {'classifier': [KNeighborsClassifier()],
     'classifier__n_neighbors': [3, 5, 7],
     'classifier__weights': ['uniform', 'distance'],
     'classifier__algorithm': ['ball_tree', 'kd_tree', 'brute']},

    {'classifier': [DecisionTreeClassifier()],
     'classifier__max_depth': [None, 10, 20],
     'classifier__min_samples_split': [2, 10],
     'classifier__min_samples_leaf': [1, 5]},

    {'classifier': [GaussianNB()],
     'classifier__var_smoothing': [1e-9, 1e-8, 1e-7]},

    {'classifier': [AdaBoostClassifier()],
     'classifier__n_estimators': [50, 100],
     'classifier__learning_rate': [0.01, 0.1, 1],
     'classifier__estimator': [DecisionTreeClassifier(max_depth=1)]},

    {'classifier': [ExtraTreesClassifier()],
     'classifier__n_estimators': [50, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [None, 10, 20],
     'classifier__min_samples_split': [2, 10],
     'classifier__min_samples_leaf': [1, 5]},
]

fitter.run('a lot', param_grid, high_X_train, high_y_train)
# Out:
# Fitting 5 folds for each of 148 candidates, totalling 740 fits
# see results dataframe by accessing the object's .result(run_name)

# %%
fitter.result('a lot').sort_values('mean_test_score', ascending=False)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        3.140798      0.207011         0.115000        0.007642
# 1        4.840998      1.600826         0.156401        0.057386
# 15       3.341001      0.192444         0.124000        0.012378
# 4        3.093603      0.294704         0.125197        0.010906
# 5        3.594799      0.243836         0.122400        0.017095
# ..            ...           ...              ...             ...
# 73       3.065939      0.111803         0.265056        0.011079
# 61       3.177905      0.404880         0.313599        0.045077
# 68       2.883122      0.163767         0.243801        0.032121
# 62       3.095008      0.433348         0.287406        0.014696
# 74       2.887596      0.100267         0.270401        0.015667
#
#                      param_classifier param_classifier__C  \
# 0   LogisticRegression(max_iter=1000)                   3
# 1   LogisticRegression(max_iter=1000)                   3
# 15  LogisticRegression(max_iter=1000)                 100
# 4   LogisticRegression(max_iter=1000)                  10
# 5   LogisticRegression(max_iter=1000)                  10
# ..                                ...                 ...
# 73             KNeighborsClassifier()                 NaN
# 61             KNeighborsClassifier()                 NaN
# 68             KNeighborsClassifier()                 NaN
# 62             KNeighborsClassifier()                 NaN
# 74             KNeighborsClassifier()                 NaN
#
#    param_classifier__penalty param_classifier__solver  \
# 0                         l1                liblinear
# 1                         l1                     saga
# 15                        l2                     saga
# 4                         l1                liblinear
# 5                         l1                     saga
# ..                       ...                      ...
# 73                       NaN                      NaN
# 61                       NaN                      NaN
# 68                       NaN                      NaN
# 62                       NaN                      NaN
# 74                       NaN                      NaN
#
#    param_classifier__max_depth param_classifier__max_features  ...  \
# 0                          NaN                            NaN  ...
# 1                          NaN                            NaN  ...
# 15                         NaN                            NaN  ...
# 4                          NaN                            NaN  ...
# 5                          NaN                            NaN  ...
# ..                         ...                            ...  ...
# 73                         NaN                            NaN  ...
# 61                         NaN                            NaN  ...
# 68                         NaN                            NaN  ...
# 62                         NaN                            NaN  ...
# 74                         NaN                            NaN  ...
#
#    param_classifier__estimator  \
# 0                          NaN
# 1                          NaN
# 15                         NaN
# 4                          NaN
# 5                          NaN
# ..                         ...
# 73                         NaN
# 61                         NaN
# 68                         NaN
# 62                         NaN
# 74                         NaN
#
#                                                params split0_test_score  \
# 0   {'classifier': LogisticRegression(max_iter=100...          3.563949
# 1   {'classifier': LogisticRegression(max_iter=100...          3.563949
# 15  {'classifier': LogisticRegression(max_iter=100...          3.563949
# 4   {'classifier': LogisticRegression(max_iter=100...          3.563949
# 5   {'classifier': LogisticRegression(max_iter=100...          3.563949
# ..                                                ...               ...
# 73  {'classifier': KNeighborsClassifier(), 'classi...          2.171491
# 61  {'classifier': KNeighborsClassifier(), 'classi...          2.171491
# 68  {'classifier': KNeighborsClassifier(), 'classi...          1.565956
# 62  {'classifier': KNeighborsClassifier(), 'classi...          1.565956
# 74  {'classifier': KNeighborsClassifier(), 'classi...          1.565956
#
#    split1_test_score split2_test_score split3_test_score split4_test_score  \
# 0           3.445613          4.024599          5.189658          5.334287
# 1           3.445613          4.024599          5.189658          5.334287
# 15          3.445613          4.024599          5.189658          5.334287
# 4           3.445613          4.024599          5.189658          5.334287
# 5           3.445613          4.024599          5.189658          5.334287
# ..               ...               ...               ...               ...
# 73          1.963469          1.376532          1.411713          2.027311
# 61          1.963469          1.376532          1.411713          2.027311
# 68          1.571470          1.508361          1.887930          1.622676
# 62          1.571470          1.508361          1.887930          1.622676
# 74          1.571470          1.508361          1.887930          1.622676
#
#    mean_test_score std_test_score rank_test_score
# 0         4.311621       0.801019               1
# 1         4.311621       0.801019               1
# 15        4.311621       0.801019               1
# 4         4.311621       0.801019               1
# 5         4.311621       0.801019               1
# ..             ...            ...             ...
# 73        1.790103       0.330454             143
# 61        1.790103       0.330454             143
# 68        1.631279       0.133339             146
# 62        1.631279       0.133339             146
# 74        1.631279       0.133339             146
#
# [148 rows x 28 columns]

# %%
fitter.predict('a lot', test_data, export=True)
# Out:
#            id         0
# 0     K751808  0.013289
# 1     K837351  0.017357
# 2     K548114  0.016381
# 3     K736156  0.012955
# 4     K508080  0.036997
# ...       ...       ...
# 1677  K588314  0.015317
# 1678  K826807  0.066690
# 1679  K982731  0.045067
# 1680  K623037  0.073934
# 1681  K883413  0.036944
#
# [1682 rows x 2 columns]

# %%
train_data['target'].value_counts()
# Out:
# 0    4299
# 1     745
# Name: target, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE, SMOTENC
from imblearn.pipeline import Pipeline as imbpipe

# %%
tes = date_and_id(X_train)
tes = imputer.fit_transform(tes)
oversampler = SMOTENC(categorical_features=categorical_columns).fit_resample(tes, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 tes = date_and_id(X_train)
#       2 tes = imputer.fit_transform(tes)
# ----> 3 oversampler = SMOTENC(categorical_features=categorical_columns).fit_resample(tes, y_train)
#
# File c:\Python310\lib\site-packages\imblearn\base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
#     207 self._validate_params()
# --> 208 return super().fit_resample(X, y)
#
# File c:\Python310\lib\site-packages\imblearn\base.py:112, in SamplerMixin.fit_resample(self, X, y)
#     106 X, y, binarize_y = self._check_X_y(X, y)
#     108 self.sampling_strategy_ = check_sampling_strategy(
#     109     self.sampling_strategy, y, self._sampling_type
#     110 )
# --> 112 output = self._fit_resample(X, y)
#     114 y_ = (
#     115     label_binarize(output[1], classes=np.unique(y)) if binarize_y else output[1]
#     116 )
#     118 X_, y_ = arrays_transformer.transform(output[0], y_)
#
# File c:\Python310\lib\site-packages\imblearn\over_sampling\_smote\base.py:665, in SMOTENC._fit_resample(self, X, y)
#     662     self.categorical_encoder_ = clone(self.categorical_encoder)
#     664 # the input of the OneHotEncoder needs to be dense
# --> 665 X_ohe = self.categorical_encoder_.fit_transform(
#     666     X_categorical.toarray() if sparse.issparse(X_categorical) else X_categorical
#     667 )
#     668 if not sparse.issparse(X_ohe):
#     669     X_ohe = sparse.csr_matrix(X_ohe, dtype=dtype_ohe)
#
# File c:\Python310\lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File c:\Python310\lib\site-packages\sklearn\base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Python310\lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File c:\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:1011, in OneHotEncoder.transform(self, X)
#    1009 if transform_output != "default" and self.sparse_output:
#    1010     capitalize_transform_output = transform_output.capitalize()
# -> 1011     raise ValueError(
#    1012         f"{capitalize_transform_output} output does not support sparse data."
#    1013         f" Set sparse_output=False to output {transform_output} dataframes or"
#    1014         f" disable {capitalize_transform_output} output via"
#    1015         '` ohe.set_output(transform="default").'
#    1016     )
#    1018 # validation of X happens in _check_X called by _transform
#    1019 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1020     "ignore",
#    1021     "infrequent_if_exist",
#    1022 }
#
# ValueError: Pandas output does not support sparse data. Set sparse_output=False to output pandas dataframes or disable Pandas output via` ohe.set_output(transform="default").

# %%
oversampler = SMOTENC(categorical_features=categorical_columns, categorical_encoder=OneHotEncoder(sparse_output=False))

# %%
# The preprocessing-classifier pipeline

p3 = Pipeline(steps=[
    ('trfm', transformer),
    ('rffs', SelectFromModel(RandomForestClassifier(random_state=0), threshold=0.01)),
    ('corr', RemoveCorrelatedFeatures(threshold=0.7)),
    ('classifier', LogisticRegression())
])

# %%
p2 = imbpipe(steps=[
    ('dtid', date_id_preprocessor),
    ('impu', imputer),
    ('over', oversampler)
])

# %%
smote_X_train, smote_y_train = p2.fit_resample(X_train, y_train)

# %%
# Everything under the sun because why not

param_grid = [
    {'classifier': [LogisticRegression(max_iter=1000)],
     'classifier__C': [3, 10, 30, 100],
     'classifier__solver': ['liblinear', 'saga'],
     'classifier__penalty': ['l1', 'l2']},
    
    {'classifier': [RandomForestClassifier()],
     'classifier__n_estimators': [50, 75, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [10, 20, 30]},
    
    {'classifier': [GradientBoostingClassifier()],
     'classifier__n_estimators': [50, 100, 150],
     'classifier__learning_rate': [0.1, 0.15, 0.2],
     'classifier__max_depth': [3, 5, 7]},

    {'classifier': [KNeighborsClassifier()],
     'classifier__n_neighbors': [3, 5, 7],
     'classifier__weights': ['uniform', 'distance'],
     'classifier__algorithm': ['ball_tree', 'kd_tree', 'brute']},

    {'classifier': [DecisionTreeClassifier()],
     'classifier__max_depth': [None, 10, 20],
     'classifier__min_samples_split': [2, 10],
     'classifier__min_samples_leaf': [1, 5]},

    {'classifier': [GaussianNB()],
     'classifier__var_smoothing': [1e-9, 1e-8, 1e-7]},

    {'classifier': [AdaBoostClassifier()],
     'classifier__n_estimators': [50, 100],
     'classifier__learning_rate': [0.01, 0.1, 1],
     'classifier__estimator': [DecisionTreeClassifier(max_depth=1)]},

    {'classifier': [ExtraTreesClassifier()],
     'classifier__n_estimators': [50, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [None, 10, 20],
     'classifier__min_samples_split': [2, 10],
     'classifier__min_samples_leaf': [1, 5]},
]

# Define the parameter grid for all the classifiers we want to try

# Define custom metric (profit at top 20 prediction)

def profit_top_20(y_true, y_pred):
    dft = y_true.to_frame()
    dft['y_pred'] = y_pred
    dft = dft.sort_values('y_pred', ascending=False).head(20)
    dft = dft[dft['target'] == 1]
    profit = smote_X_train['average cost min'][dft.index].sum()
    return profit

param_grid = [
    {'classifier': [LogisticRegression(max_iter=1000)],
     'classifier__C': [1, 3, 10, 30],
     'classifier__solver': ['liblinear', 'saga'],  # 'liblinear' and 'saga' work well with small datasets and L1 penalty
     'classifier__penalty': ['l1', 'l2']},
    
    {'classifier': [RandomForestClassifier()],
     'classifier__n_estimators': [50, 75, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [10, 20, 30]},
    
    {'classifier': [GradientBoostingClassifier()],
     'classifier__n_estimators': [50, 100, 150],
     'classifier__learning_rate': [0.1, 0.3, 1, 3],
     'classifier__max_depth': [3, 5, 7]}
]

grid_search = GridSearchCV(p3, param_grid, cv=5, scoring=make_scorer(profit_top_20, response_method="predict_proba", greater_is_better=True), n_jobs=-1, verbose=2)
grid_search.fit(smote_X_train, smote_y_train)
# Out:
# Fitting 5 folds for each of 61 candidates, totalling 305 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('trfm',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehot',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['Tariff_OK',
#                                                                           'Usage_Band',
#                                                                           'Gender',
#                                                                           'high '
#                                                                           'Dropped '
#                                                                           'calls',
#                                                                           'Handset',
#                                                                           'No '
#                                                                           'Usage',
#                                                                           'tariff']),
#                                                                         ('quant',
#                                                                          QuantileTransformer(output_distribution='normal',
#                                                                                              random_stat...
#                           'classifier__max_depth': [10, 20, 30],
#                           'classifier__max_features': ['sqrt', 'log2'],
#                           'classifier__n_estimators': [50, 75, 100]},
#                          {'classifier': [GradientBoostingClassifier()],
#                           'classifier__learning_rate': [0.1, 0.15, 0.2],
#                           'classifier__max_depth': [3, 5, 7],
#                           'classifier__n_estimators': [50, 100, 150]}],
#              scoring=make_scorer(profit_top_20, response_method='predict_proba'),
#              verbose=2)

# %%
res = grid_search.predict_proba(pt.fit_transform(test_data))
res = pd.concat([test_data['id'], pd.Series([i[1] for i in res])], axis=1)

# %%
pt = imbpipe(steps=[
    ('dtid', date_id_preprocessor),
    ('impu', imputer),
    # ('over', oversampler)
])

# %%
res.to_csv('smotenc.csv', header=False, index=False)

# %%
oversampler2 = RandomOverSampler()

p4 = imbpipe(steps=[
    ('dtid', date_id_preprocessor),
    ('impu', imputer),
    ('over', oversampler2)
])

# %%
ros_X_train, ros_y_train = p4.fit_resample(X_train, y_train)

# %%
ros_X_train['target'] = ros_y_train

# %%
high_spenders_threshold = np.quantile(ros_X_train['average cost min'], 0.92)
high_spenders_data = ros_X_train[ros_X_train['average cost min'] > high_spenders_threshold]
ros_y_train = ros_X_train['target']
ros_X_train = ros_X_train.drop('target', axis=1)

# %%
param_grid = [
    {'classifier': [LogisticRegression(max_iter=1000)],
     'classifier__C': [1, 3, 10, 30],
     'classifier__solver': ['liblinear', 'saga'],  # 'liblinear' and 'saga' work well with small datasets and L1 penalty
     'classifier__penalty': ['l1', 'l2']},
    
    {'classifier': [RandomForestClassifier()],
     'classifier__n_estimators': [50, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [10, 20],
     'classifier__ccp_alpha': [0.001, 0.01, 0.1]},
    
    {'classifier': [GradientBoostingClassifier()],
     'classifier__n_estimators': [50, 100, 150],
     'classifier__learning_rate': [0.1, 0.3, 1, 3],
     'classifier__max_depth': [2, 3, 4, 5]}
]

grid_search3 = GridSearchCV(p3, param_grid, cv=5, scoring=make_scorer(profit_top_20, response_method="predict_proba", greater_is_better=True), n_jobs=-1, verbose=2)
grid_search3.fit(ros_X_train, ros_y_train)
# Out:
# Fitting 5 folds for each of 88 candidates, totalling 440 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('trfm',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehot',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['Tariff_OK',
#                                                                           'Usage_Band',
#                                                                           'Gender',
#                                                                           'high '
#                                                                           'Dropped '
#                                                                           'calls',
#                                                                           'Handset',
#                                                                           'No '
#                                                                           'Usage',
#                                                                           'tariff']),
#                                                                         ('quant',
#                                                                          QuantileTransformer(output_distribution='normal',
#                                                                                              random_stat...
#                           'classifier__max_depth': [10, 20],
#                           'classifier__max_features': ['sqrt', 'log2'],
#                           'classifier__n_estimators': [50, 100]},
#                          {'classifier': [GradientBoostingClassifier()],
#                           'classifier__learning_rate': [0.1, 0.3, 1, 3],
#                           'classifier__max_depth': [2, 3, 4, 5],
#                           'classifier__n_estimators': [50, 100, 150]}],
#              scoring=make_scorer(profit_top_20, response_method='predict_proba'),
#              verbose=2)

# %%
pd.DataFrame(grid_search3.cv_results_).sort_values('mean_test_score', ascending=False).head(30)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 43       5.673215      0.860467         0.108399        0.015266
# 2        4.111799      0.611319         0.115802        0.019863
# 52       4.801806      0.529737         0.094599        0.005851
# 64       5.175601      1.047060         0.111801        0.034055
# 7        4.109799      0.142681         0.096601        0.010249
# 23       5.530398      0.170529         0.116399        0.008016
# 1        4.850599      0.599887         0.106200        0.011736
# 12       3.814401      0.165497         0.096001        0.005177
# 13       4.895600      0.653005         0.112000        0.020445
# 14       4.366399      0.673443         0.117601        0.025382
# 9        4.960203      0.668750         0.106797        0.013426
# 8        4.370001      0.602856         0.107999        0.021362
# 15       4.134797      0.134525         0.090605        0.003555
# 11       4.802796      0.894219         0.105001        0.014086
# 5        5.417400      0.504943         0.132400        0.029125
# 4        3.956601      0.291964         0.099000        0.010808
# 10       3.801001      0.521601         0.100599        0.018488
# 0        4.144598      0.556191         0.103400        0.017430
# 6        3.920601      0.548172         0.106999        0.022724
# 41       6.087517      0.752963         0.102001        0.013667
# 22       4.686003      0.350825         0.103397        0.008311
# 53       5.760200      0.730316         0.098000        0.013490
# 61       6.585460      1.123189         0.107000        0.020278
# 3        4.277200      0.622761         0.095399        0.009135
# 29       6.289200      0.867243         0.118800        0.016017
# 65       6.481718      1.254097         0.101002        0.014184
# 42       6.735518      0.431345         0.094799        0.002561
# 21       5.855200      0.325060         0.120601        0.010052
# 50       9.480941      1.464923         0.109402        0.019631
# 51      11.386543      1.396742         0.096800        0.001166
#
#                      param_classifier param_classifier__C  \
# 43       GradientBoostingClassifier()                 NaN
# 2   LogisticRegression(max_iter=1000)                   1
# 52       GradientBoostingClassifier()                 NaN
# 64       GradientBoostingClassifier()                 NaN
# 7   LogisticRegression(max_iter=1000)                   3
# 23           RandomForestClassifier()                 NaN
# 1   LogisticRegression(max_iter=1000)                   1
# 12  LogisticRegression(max_iter=1000)                  30
# 13  LogisticRegression(max_iter=1000)                  30
# 14  LogisticRegression(max_iter=1000)                  30
# 9   LogisticRegression(max_iter=1000)                  10
# 8   LogisticRegression(max_iter=1000)                  10
# 15  LogisticRegression(max_iter=1000)                  30
# 11  LogisticRegression(max_iter=1000)                  10
# 5   LogisticRegression(max_iter=1000)                   3
# 4   LogisticRegression(max_iter=1000)                   3
# 10  LogisticRegression(max_iter=1000)                  10
# 0   LogisticRegression(max_iter=1000)                   1
# 6   LogisticRegression(max_iter=1000)                   3
# 41       GradientBoostingClassifier()                 NaN
# 22           RandomForestClassifier()                 NaN
# 53       GradientBoostingClassifier()                 NaN
# 61       GradientBoostingClassifier()                 NaN
# 3   LogisticRegression(max_iter=1000)                   1
# 29           RandomForestClassifier()                 NaN
# 65       GradientBoostingClassifier()                 NaN
# 42       GradientBoostingClassifier()                 NaN
# 21           RandomForestClassifier()                 NaN
# 50       GradientBoostingClassifier()                 NaN
# 51       GradientBoostingClassifier()                 NaN
#
#    param_classifier__penalty param_classifier__solver  \
# 43                       NaN                      NaN
# 2                         l2                liblinear
# 52                       NaN                      NaN
# 64                       NaN                      NaN
# 7                         l2                     saga
# 23                       NaN                      NaN
# 1                         l1                     saga
# 12                        l1                liblinear
# 13                        l1                     saga
# 14                        l2                liblinear
# 9                         l1                     saga
# 8                         l1                liblinear
# 15                        l2                     saga
# 11                        l2                     saga
# 5                         l1                     saga
# 4                         l1                liblinear
# 10                        l2                liblinear
# 0                         l1                liblinear
# 6                         l2                liblinear
# 41                       NaN                      NaN
# 22                       NaN                      NaN
# 53                       NaN                      NaN
# 61                       NaN                      NaN
# 3                         l2                     saga
# 29                       NaN                      NaN
# 65                       NaN                      NaN
# 42                       NaN                      NaN
# 21                       NaN                      NaN
# 50                       NaN                      NaN
# 51                       NaN                      NaN
#
#    param_classifier__ccp_alpha param_classifier__max_depth  ...  \
# 43                         NaN                           3  ...
# 2                          NaN                         NaN  ...
# 52                         NaN                           2  ...
# 64                         NaN                           2  ...
# 7                          NaN                         NaN  ...
# 23                       0.001                          20  ...
# 1                          NaN                         NaN  ...
# 12                         NaN                         NaN  ...
# 13                         NaN                         NaN  ...
# 14                         NaN                         NaN  ...
# 9                          NaN                         NaN  ...
# 8                          NaN                         NaN  ...
# 15                         NaN                         NaN  ...
# 11                         NaN                         NaN  ...
# 5                          NaN                         NaN  ...
# 4                          NaN                         NaN  ...
# 10                         NaN                         NaN  ...
# 0                          NaN                         NaN  ...
# 6                          NaN                         NaN  ...
# 41                         NaN                           2  ...
# 22                       0.001                          20  ...
# 53                         NaN                           2  ...
# 61                         NaN                           5  ...
# 3                          NaN                         NaN  ...
# 29                        0.01                          20  ...
# 65                         NaN                           2  ...
# 42                         NaN                           2  ...
# 21                       0.001                          20  ...
# 50                         NaN                           5  ...
# 51                         NaN                           5  ...
#
#    param_classifier__learning_rate  \
# 43                             0.1
# 2                              NaN
# 52                             0.3
# 64                               1
# 7                              NaN
# 23                             NaN
# 1                              NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 9                              NaN
# 8                              NaN
# 15                             NaN
# 11                             NaN
# 5                              NaN
# 4                              NaN
# 10                             NaN
# 0                              NaN
# 6                              NaN
# 41                             0.1
# 22                             NaN
# 53                             0.3
# 61                             0.3
# 3                              NaN
# 29                             NaN
# 65                               1
# 42                             0.1
# 21                             NaN
# 50                             0.1
# 51                             0.1
#
#                                                params split0_test_score  \
# 43  {'classifier': GradientBoostingClassifier(), '...          5.176099
# 2   {'classifier': LogisticRegression(max_iter=100...          5.193495
# 52  {'classifier': GradientBoostingClassifier(), '...          5.052874
# 64  {'classifier': GradientBoostingClassifier(), '...          4.778453
# 7   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 23  {'classifier': RandomForestClassifier(), 'clas...          3.418798
# 1   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 12  {'classifier': LogisticRegression(max_iter=100...          4.517294
# 13  {'classifier': LogisticRegression(max_iter=100...          4.517294
# 14  {'classifier': LogisticRegression(max_iter=100...          4.517294
# 9   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 8   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 15  {'classifier': LogisticRegression(max_iter=100...          4.517294
# 11  {'classifier': LogisticRegression(max_iter=100...          4.517294
# 5   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 4   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 10  {'classifier': LogisticRegression(max_iter=100...          4.517294
# 0   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 6   {'classifier': LogisticRegression(max_iter=100...          4.517294
# 41  {'classifier': GradientBoostingClassifier(), '...          3.550552
# 22  {'classifier': RandomForestClassifier(), 'clas...          3.349501
# 53  {'classifier': GradientBoostingClassifier(), '...          4.350768
# 61  {'classifier': GradientBoostingClassifier(), '...          4.090838
# 3   {'classifier': LogisticRegression(max_iter=100...          4.367146
# 29  {'classifier': RandomForestClassifier(), 'clas...          3.280392
# 65  {'classifier': GradientBoostingClassifier(), '...          4.184332
# 42  {'classifier': GradientBoostingClassifier(), '...          4.205273
# 21  {'classifier': RandomForestClassifier(), 'clas...          3.581730
# 50  {'classifier': GradientBoostingClassifier(), '...          3.582807
# 51  {'classifier': GradientBoostingClassifier(), '...          3.517519
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 43          3.268242           3.663619           3.680448           4.435490
# 2           3.123746           4.069964           3.474262           3.959773
# 52          3.282544           3.239807           3.536049           4.498721
# 64          3.238441           4.155755           3.505250           3.717314
# 7           3.185326           4.101594           3.414570           4.074699
# 23          4.013157           4.691968           3.362089           3.768925
# 1           3.185326           4.101594           3.414570           3.960405
# 12          3.185634           4.101594           3.447474           3.902329
# 13          3.185634           4.101594           3.447474           3.902329
# 14          3.185634           4.101594           3.441410           3.902329
# 9           3.185634           4.101594           3.441410           3.902329
# 8           3.185634           4.101594           3.441410           3.902329
# 15          3.185326           4.101594           3.441410           3.902329
# 11          3.185326           4.101594           3.414570           3.902329
# 5           3.185326           4.101594           3.414570           3.902329
# 4           3.185326           4.101594           3.414570           3.902329
# 10          3.135265           4.101594           3.414570           3.902329
# 0           3.135265           4.101594           3.414570           3.902329
# 6           3.135823           4.096871           3.414570           3.902329
# 41          3.401848           4.149773           3.223379           4.702046
# 22          3.579606           4.331763           3.955151           3.647805
# 53          3.217256           3.790186           3.183979           4.230946
# 61          3.686994           3.030334           3.720281           4.237756
# 3           3.123746           4.059120           3.143107           3.959773
# 29          3.864612           4.015547           3.982678           3.414190
# 65          3.892633           3.144678           3.268361           3.937800
# 42          3.438137           3.117297           3.267287           4.340936
# 21          4.406049           3.220409           3.509296           3.500711
# 50          3.915625           3.123097           3.478569           3.986583
# 51          3.923292           3.111621           3.316736           4.203775
#
#     mean_test_score  std_test_score  rank_test_score
# 43         4.044780        0.680231                1
# 2          3.964248        0.702677                2
# 52         3.921999        0.725911                3
# 64         3.879043        0.540695                4
# 7          3.858697        0.487870                5
# 23         3.850988        0.482927                6
# 1          3.835838        0.479825                7
# 12         3.830865        0.471783                8
# 13         3.830865        0.471783                8
# 14         3.829652        0.472774               10
# 9          3.829652        0.472774               10
# 8          3.829652        0.472774               10
# 15         3.829591        0.472858               13
# 11         3.824223        0.477365               14
# 5          3.824223        0.477365               14
# 4          3.824223        0.477365               14
# 10         3.814210        0.490991               17
# 0          3.814210        0.490991               17
# 6          3.813377        0.490287               19
# 41         3.805519        0.545732               20
# 22         3.772765        0.339947               21
# 53         3.754627        0.489476               22
# 61         3.753241        0.418759               23
# 3          3.730578        0.505778               24
# 29         3.711484        0.304523               25
# 65         3.685561        0.405435               26
# 42         3.673786        0.501601               27
# 21         3.643639        0.400675               28
# 50         3.617336        0.313063               29
# 51         3.614588        0.398385               30
#
# [30 rows x 22 columns]

# %%
param_grid = [
    {'classifier': [LogisticRegression(max_iter=1000)],
     'classifier__C': [1, 3, 10, 30],
     'classifier__solver': ['liblinear', 'saga'],  # 'liblinear' and 'saga' work well with small datasets and L1 penalty
     'classifier__penalty': ['l1', 'l2']},
    
    {'classifier': [RandomForestClassifier()],
     'classifier__n_estimators': [50, 100],
     'classifier__max_features': ['sqrt', 'log2'],
     'classifier__max_depth': [10, 20],
     'classifier__ccp_alpha': [0.001, 0.01, 0.1]},
    
    {'classifier': [GradientBoostingClassifier()],
     'classifier__n_estimators': [50, 100, 150],
     'classifier__learning_rate': [0.1, 0.3, 1, 3],
     'classifier__max_depth': [2, 3, 4, 5]}
]

grid_search4 = GridSearchCV(p3, param_grid, cv=5, scoring=make_scorer(profit_top_20, response_method="predict_proba", greater_is_better=True), n_jobs=-1, verbose=2)
grid_search4.fit(ros_X_train, ros_y_train)
# Out:
# Fitting 5 folds for each of 88 candidates, totalling 440 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('trfm',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehot',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['Tariff_OK',
#                                                                           'Usage_Band',
#                                                                           'Gender',
#                                                                           'high '
#                                                                           'Dropped '
#                                                                           'calls',
#                                                                           'Handset',
#                                                                           'No '
#                                                                           'Usage',
#                                                                           'tariff']),
#                                                                         ('quant',
#                                                                          QuantileTransformer(output_distribution='normal',
#                                                                                              random_stat...
#                           'classifier__max_depth': [10, 20],
#                           'classifier__max_features': ['sqrt', 'log2'],
#                           'classifier__n_estimators': [50, 100]},
#                          {'classifier': [GradientBoostingClassifier()],
#                           'classifier__learning_rate': [0.1, 0.3, 1, 3],
#                           'classifier__max_depth': [2, 3, 4, 5],
#                           'classifier__n_estimators': [50, 100, 150]}],
#              scoring=make_scorer(profit_top_20, response_method='predict_proba'),
#              verbose=2)

# %%
pd.DataFrame(grid_search4.cv_results_).sort_values('mean_test_score', ascending=False).head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.DataFrame(grid_search4.cv_results_).sort_values('mean_test_score', ascending=False).head(30)
#
# NameError: name 'pd' is not defined
